# %% [markdown]
# # 1. Les expressions régulières : à quoi ça sert ?
#
# Chercher un mot dans un texte est une tâche facile, c'est l'objectif de la méthode find attachée aux chaînes de caractères, elle suffit encore lorsqu'on cherche un mot au pluriel ou au singulier mais il faut l'appeler au moins deux fois pour chercher ces deux formes. Pour des expressions plus compliquées, il est conseillé d'utiliser les expressions régulières. C'est une fonctionnalité qu'on retrouve dans beaucoup de langages. C'est une forme de grammaire qui permet de rechercher des expressions.

# %% [markdown]
# Lorsqu'on remplit un formulaire, on voit souvent le format ``"MM/JJ/AAAA"`` qui précise sous quelle forme on s'attend à ce qu’une date soit écrite. Les expressions régulières permettent de définir également ce format et de chercher dans un texte toutes les chaînes de caractères qui sont conformes à ce format.
#
# La liste qui suit contient des dates de naissance. On cherche à obtenir toutes les dates de cet exemple sachant que les jours ou les mois contiennent un ou deux chiffres, les années deux ou quatre.

# %%
s = """date 0 : 14/9/2000
date 1 : 20/04/1971     date 2 : 14/09/1913     date 3 : 2/3/1978
date 4 : 1/7/1986     date 5 : 7/3/47     date 6 : 15/10/1914
date 7 : 08/03/1941     date 8 : 8/1/1980     date 9 : 30/6/1976"""

# %% [markdown]
# Le premier chiffre du jour est soit 0, 1, 2, ou 3 ; ceci se traduit par ``[0-3]``. Le second chiffre est compris entre 0 et 9, soit ``[0-9]``. Le format des jours est traduit par ``[0-3][0-9]``. Mais le premier jour est facultatif, ce qu'on précise avec le symbole ? : ``[0-3]?[0-9]``. Les mois suivent le même principe : ``[0-1]?[0-9]``. Pour les années, ce sont les deux premiers chiffres qui sont facultatifs, le symbole ? s'appliquent sur les deux premiers chiffres, ce qu'on précise avec des parenthèses : ``([0-2][0-9])?[0-9][0-9]``. Le format final d'une date devient :

# %%
"[0-3]?[0-9]/[0-1]?[0-9]/([0-2][0-9])?[0-9][0-9]"

# %% [markdown]
# Le module re gère les expressions régulières, celui-ci traite différemment les parties de l'expression régulière qui sont entre parenthèses de celles qui ne le sont pas : c'est un moyen de dire au module re que nous nous intéressons à telle partie de l'expression qui est signalée entre parenthèses. Comme la partie qui nous intéresse - une date - concerne l'intégralité de l'expression régulière, il faut insérer celle-ci entre parenthèses.
#
# La première étape consiste à construire l'expression régulière, la seconde à rechercher toutes les fois qu'un morceau de la chaîne s définie plus haut correspond à l’expression régulière.

# %%
import re
# première étape : construction
expression = re.compile("([0-3]?[0-9]/[0-1]?[0-9]/([0-2][0-9])?[0-9][0-9])")
# seconde étape : recherche
res = expression.findall(s)
print(res)

# %%
res

# %%
expression.findall?

# %% [markdown]
# Le résultat une liste de couples dont chaque élément correspond aux parties comprises entre parenthèses qu'on appelle des groupes. Lorsque les expressions régulières sont utilisées, on doit d'abord se demander comment définir ce qu’on cherche puis quelles fonctions utiliser pour obtenir les résultats de cette recherche. Les deux paragraphes qui suivent y répondent.

# %% [markdown]
# ## 1.1 Syntaxe
#
# La syntaxe des expressions régulières est décrite sur le site officiel de python. La page [Regular Expression Syntax](https://docs.python.org/3/library/re.html?highlight=re#regular-expression-syntax) décrit comment se servir des expressions régulières, les deux pages sont en anglais. Comme toute grammaire, celle des expressions régulières est susceptible d’évoluer au fur et à mesure des versions du langage python.

# %% [markdown]
# ## 1.2 Les ensembles de caractères
# Lors d’une recherche, on s’intéresse aux caractères et souvent aux classes de caractères : on cherche un chiffre, une lettre, un caractère dans un ensemble précis ou un caractère qui n’appartient pas à un ensemble précis. Certains ensembles sont prédéfinis, d’autres doivent être définis à l’aide de crochets.
#
# Pour définir un ensemble de caractères, il faut écrire cet ensemble entre crochets : [0123456789] désigne un chiffre. Comme c’est une séquence de caractères consécutifs, on peut résumer cette écriture en [0-9]. Pour inclure les symboles -, +, il suffit d’écrire : [-0-9+]. Il faut penser à mettre le symbole - au début pour éviter qu’il ne désigne une séquence.
#
# Le caractère ^ inséré au début du groupe signifie que le caractère cherché ne doit pas être un de ceux qui suivent. Le tableau suivant décrit les ensembles prédéfinis et leur équivalent en terme d’ensemble de caractères :

# %% [markdown]
# * ``.`` désigne tout caractère non spécial quel qu'il soit.
# * ``\d`` désigne tout chiffre, est équivalent à ``[0-9]``.
# * ``\D`` désigne tout caractère différent d'un chiffre, est équivalent à ``[^0-9]``.
# * ``\s`` désigne tout espace ou caractère approché, est équivalent à ``[\; \t\n\r\f\v]``. Ces caractères sont spéciaux, les plus utilisés sont ``\t`` qui est une tabulation, ``\n`` qui est une fin de ligne et qui ``\r`` qui est un retour à la ligne.
# * ``\S`` désigne tout caractère différent d'un espace, est équivalent à ``[^ \t\n\r\f\v]``.
# * ``\w`` désigne tout lettre ou chiffre, est équivalent à ``[a-zA-Z0-9_]``.
# * ``\W`` désigne tout caractère différent d'une lettre ou d'un chiffre, est équivalent à ``[^a-zA-Z0-9_]``.
# * ``^`` désigne le début d'un mot sauf s'il est placé entre crochets.
# * ``$`` désigne la fin d'un mot sauf s'il est placé entre crochets.

# %% [markdown]
# A l'instar des chaînes de caractères, comme le caractère ``\`` est un caractère spécial, il faut le doubler : ``[\\]``.
#
# Le caractère ``\`` est déjà un caractère spécial pour les chaînes de caractères en python, il faut donc le quadrupler pour l'insérer dans un expression régulière. L'expression suivante filtre toutes les images dont l’extension est png et qui sont enregistrées dans un répertoire image.

# %%
import re
s = "something\\support\\vba\\image/vbatd1_4.png"
print(re.compile("[\\\\/]image[\\\\/].*[.]png").search(s))  # résultat positif
print(re.compile("[\\\\/]image[\\\\/].*[.]png").search(s))  # même résultat

# %% [markdown]
# ## 1.3 Les multiplicateurs
# Les multiplicateurs permettent de définir des expressions régulières comme : un mot entre six et huit lettres qu’on écrira ``[\w]{6,8}``. Le tableau suivant donne la liste des multiplicateurs principaux :

# %% [markdown]
# * ``*`` présence de l'ensemble de caractères qui précède entre 0 fois et l'infini
# * ``+`` présence de l'ensemble de caractères qui précède entre 1 fois et l'infini
# * ``?`` présence de l'ensemble de caractères qui précède entre 0 et 1 fois
# * ``{m,n}`` présence de l'ensemble de caractères qui précède entre *m* et *n* fois, si *m=n*, cette expression peut être résumée par ``{n}``.
# * ``(?!(...))`` absence du groupe désigné par les points de suspensions.

# %% [markdown]
# L’algorithme des expressions régulières essaye toujours de faire correspondre le plus grand morceau à l’expression régulière.

# %%
"<h1>mot</h1>"

# %% [markdown]
# ``<.*>`` correspond avec ``<h1>``, ``</h1>`` ou encore ``<h1>mot</h1>``.

# %% [markdown]
# Par conséquent, l’expression régulière correspond à trois morceaux. Par défaut, il prendra le plus grand. Pour choisir les plus petits, il faudra écrire les multiplicateurs comme ceci : ``*?``, ``+?``

# %%
import re
s = "<h1>mot</h1>"
print(re.compile("(<.*>)").match(s).groups())   # ('<h1>mot</h1>',)
print(re.compile("(<.*?>)").match(s).groups())  # ('<h1>',)
print(re.compile("(<.+?>)").match(s).groups())  # ('<h1>',)

# %% [markdown]
# ### Exercice 1
#
# Recherchez les dates présentes dans la phrase suivante

# %%
texte = """Je suis né le 28/12/1903 et je suis mort le 08/02/1957. Ma seconde femme est morte le 10/11/1963. 
J'ai écrit un livre intitulé 'Comprendre les fractions : les exemples en page 12/46/83' """

# %% [markdown]
# Puis dans celle-ci :

# %%
texte = """Je suis né le 28/12/1903 et je suis mort le 08/02/1957. Je me suis marié le 8/5/45. 
J'ai écrit un livre intitulé 'Comprendre les fractions : les exemples en page 12/46/83' """

# %% [markdown]
# # 2. Web Scrapping
#
# Sous ce nom se cache une pratique très utile pour toute personne souhaitant travailler sur des informations disponibles en ligne, mais n'existant pas forcément sous la forme d'un tableau *Excel*... Bref, il s'agit de récupérer des informations depuis *Internet*.

# %% [markdown]
# Le [webscraping](https://fr.wikipedia.org/wiki/Web_scraping) désigne les techniques d'extraction du contenu des sites internet. Via un programme informatique : nous allons aujourd'hui vous présenter comme créer et exécuter ces robots afin de recupérer rapidement des informations utiles à vos projets actuels ou futurs.

# %% [markdown]
# ## 2.1 Un détour par le Web : comment fonctionne un site ?
#
# Même si nous n'allons pas aujourd'hui faire un cours de web, il vous faut néanmoins certaines bases pour comprendre comment un site internet fonctionne et comment sont structurées les informations sur une page.

# %% [markdown]
# Un site Web est un ensemble de pages codées en *HTML* qui permet de décrire à la fois le contenu et la forme d'une page *Web*.
#
# ###  HTML

# %% [markdown]
# ### Les balises
#
#
# Sur une page web, vous trouverez toujours à coup sûr des éléments comme ``<head>``, ``<title>``, etc. Il  s'agit des codes qui vous permettent de structurer le contenu d'une page *HTML* et qui s'appellent des balises.
# Citons, par exemple, les balises ``<p>``, ``<h1>``, ``<h2>``, ``<h3>``, ``<strong>`` ou ``<em>``.
# Le symbole ``< >`` est une balise : il sert à indiquer le début d'une partie. Le symbole ``</ >`` indique la fin de cette partie. La plupart des balises vont par paires, avec une *balise ouvrante* et une *balise fermante* (par exemple ``<p>`` et ``</p>``).

# %% [markdown]
# #### Exemple : les balise des tableaux
#
# $$
# \begin{array}{rr} \hline
# Balise  & \text{Description} \\ \hline
# < table> & \text{Tableau} \\
# < caption>& \text{Titre du tableau} \\
# < tr> & \text{Ligne de tableau} \\
# < th> & \text{Cellule d'en-tête}\\
# < td> & \text{Cellule} \\
# < thead> & \text{Section de l'en-tête du tableau} \\
# < tbody> & \text{Section du corps du tableau} \\
# < tfoot> & \text{Section du pied du tableau} \\
# \end{array}
# $$

# %% [markdown]
# #### Exemple
#
# <table>
#    <tr>
#       <th>Prénom</th>
#       <th>Nom</th>
#       <th>Profession</th>
#    </tr>
#    <tr>
#       <td>Mike</td>
#       <td>Stuntman</td>
#       <td>Cascadeur</td>
#    </tr>
#    <tr>
#       <td>Mister</td>
#       <td>Pink</td>
#       <td>Gangster</td>
#    </tr>
# </table>

# %% [markdown]
# #### Parent et enfant
#
# Dans le cadre du langage HTML, les termes de parents (parent) et enfants (child) servent à désigner des élements emboîtés les uns dans les autres. Dans la construction suivante, par exemple :

# %% [markdown]
# On dira que l'élément ``<div>`` est le parent de l'élément ``<p>`` tandis que l'élément ``<p>`` est l'enfant de l'élément ``<div>``.

# %% [markdown]
# ----------
#
# Mais pourquoi apprendre ça pour scraper me direz-vous ?
#
# Pour bien récupérer les informations d'un site internet, il faut pouvoir comprendre sa structure et donc son code HTML. Les fonctions python qui servent au scrapping sont principalement construites pour vous permettre de naviguer entre les balises.

# %% [markdown]
# ## 2.2 Scrapper avec python
#
# Nous allons essentiellement utiliser le package [BeautifulSoup4](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) pour cet atelier, mais d'autres packages existent ([Selenium](https://selenium-python.readthedocs.io/), [Scrapy](https://scrapy.org/)...).
#
# [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) sera suffisant quand vous voudrez travailler sur des pages HTML statiques, dès que les informations que vous recherchez sont générées via l'exécution de scripts [Javascript](https://fr.wikipedia.org/wiki/JavaScript), il vous faudra passer par des outils comme Selenium.
#
# De même, si vous ne connaissez pas l'URL, il faudra passer par un framework comme [Scrapy](https://scrapy.org/), qui passe facilement d'une page à une autre ("crawl"). Scrapy est plus complexe à manipuler que [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) : si vous voulez plus de détails, rendez-vous sur la page du tutorial [Scrapy Tutorial](https://doc.scrapy.org/en/latest/intro/tutorial.html).

# %% [markdown]
# ### Utiliser BeautifulSoup
#
# Les packages pour scrapper des pages HTML :
# - [BeautifulSoup4](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) (``pip install bs4``)
# - [urllib](https://docs.python.org/3/library/urllib.html#module-urllib)

# %%
import urllib
import bs4
#help(bs4)

# %% [markdown]
# #### 1ere page HTML
#
# On va commencer facilement, prenons une page wikipedia, par exemple celle de la Ligue 1 de football : [Championnat de France de football 2019-2020](https://fr.wikipedia.org/wiki/Championnat_de_France_de_football_2019-2020). On va souhaiter récupérer la liste des équipes, ainsi que les url des pages Wikipedia de ces équipes.

# %%
# Etape 1 : se connecter à la page wikipedia et obtenir le code source

url_ligue_1 = "https://fr.wikipedia.org/wiki/Championnat_de_France_de_football_2019-2020"
    
from urllib import request

request_text = request.urlopen(url_ligue_1).read()
print(request_text[:1000])
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="fr" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Championnat de France de football 2019-2020 \xe2\x80\x94 Wikip\xc3\xa9dia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":[",\\t.","\xc2\xa0\\t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","janvier","f\xc3\xa9vrier","mars","avril","mai","juin","juillet","ao\xc3\xbbt","septembre","octobre","novembre","d\xc3\xa9cembre"],"wgRequestId":"508c6dc9-450e-4457-b16b-ba56ddda24cb","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Championnat_de_France_de_football_2019-2020","wgTitle":"Championnat de France de football 2019-2020","wgCurRevisionId":181084403,"wgRevisionId":181084403,"wgArticleId":12518858,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Page utilisant une frise chronologique","Article utilisant une I'

# %%
# Etape 2 : utiliser le package BeautifulSoup
# qui "comprend" les balises contenues dans la chaine de caractères renvoyée par la fonction request

page = bs4.BeautifulSoup(request_text, "lxml")

print(page)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="fr">
# <head>
# <meta charset="utf-8"/>
# <title>Championnat de France de football 2019-2020 — Wikipédia</title>
# <script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":[",\t."," \t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","janvier","février","mars","avril","mai","juin","juillet","août","septembre","octobre","novembre","décembre"],"wgRequestId":"508c6dc9-450e-4457-b16b-ba56ddda24cb","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Championnat_de_France_de_football_2019-2020","wgTitle":"Championnat de France de football 2019-2020","wgCurRevisionId":181084403,"wgRevisionId":181084403,"wgArticleId":12518858,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Page utilisant une frise chronologique","Article utilisant une Infobox","Portail:Football/Articles liés","Portail:Sport/Articles liés","Portail:France/Articles liés","Portail:Europe/Articles liés",
# "Portail:Monaco/Articles liés","Portail:Années 2010/Articles liés","Portail:XXIe siècle/Articles liés","Portail:Époque contemporaine/Articles liés","Portail:Années 2020/Articles liés","Championnat de France de football 2019-2020","Championnat national de football 2019-2020"],"wgPageContentLanguage":"fr","wgPageContentModel":"wikitext","wgRelevantPageName":"Championnat_de_France_de_football_2019-2020","wgRelevantArticleId":12518858,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsReferencePreviewsBeta":!0,"wgPopupsConflictsWithNavPopupGadget":!1,"wgPopupsConflictsWithRefTooltipsGadget":!1,"wgVisualEditor":{"pageLanguageCode":"fr","pageLanguageDir":"ltr","pageVariantFallbacks":"fr"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!0},
# "wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"français","wgNoticeProject":"wikipedia","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0,"wgULSPosition":"interlanguage","wgGENewcomerTasksGuidanceEnabled":!0,"wgGEAskQuestionEnabled":!0,"wgGELinkRecommendationsFrontendEnabled":!1,"wgWikibaseItemId":"Q61862323"};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","ext.timeline.styles":"ready","mediawiki.ui.button":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","mediawiki.ui.icon":"ready","jquery.tablesorter.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter",
# "mediawiki.toc","skins.vector.js","ext.gadget.ArchiveLinks","ext.gadget.MonobookToolbarStandard","ext.gadget.Wdsearch","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.growthExperiments.SuggestedEditSession"];</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});mw.user.options.set({"variant":"fr"});
# });});</script>
# <link href="/w/load.php?lang=fr&amp;modules=ext.cite.styles%7Cext.timeline.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.tablesorter.styles%7Cmediawiki.ui.button%2Cicon%7Cskins.vector.icons%2Cstyles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
# <script async="" src="/w/load.php?lang=fr&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector"></script>
# <meta content="" name="ResourceLoaderDynamicStyles"/>
# <link href="/w/load.php?lang=fr&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
# <meta content="MediaWiki 1.36.0-wmf.35" name="generator"/>
# <meta content="origin" name="referrer"/>
# <meta content="origin-when-crossorigin" name="referrer"/>
# <meta content="origin-when-cross-origin" name="referrer"/>
# <meta content="https://upload.wikimedia.org/wikipedia/fr/thumb/1/14/Ligue_1_Conforama.svg/1200px-Ligue_1_Conforama.svg.png" property="og:image"/>
# <meta content="Championnat de France de football 2019-2020 — Wikipédia" property="og:title"/>
# <meta content="website" property="og:type"/>
# <link href="//upload.wikimedia.org" rel="preconnect"/>
# <link href="//fr.m.wikipedia.org/wiki/Championnat_de_France_de_football_2019-2020" media="only screen and (max-width: 720px)" rel="alternate"/>
# <link href="/w/index.php?title=Championnat_de_France_de_football_2019-2020&amp;action=edit" rel="alternate" title="Modifier" type="application/x-wiki"/>
# <link href="/w/index.php?title=Championnat_de_France_de_football_2019-2020&amp;action=edit" rel="edit" title="Modifier"/>
# <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
# <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
# <link href="/w/opensearch_desc.php" rel="search" title="Wikipédia (fr)" type="application/opensearchdescription+xml"/>
# <link href="//fr.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
# <link href="//creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
# <link href="https://fr.wikipedia.org/wiki/Championnat_de_France_de_football_2019-2020" rel="canonical"/>
# <link href="//login.wikimedia.org" rel="dns-prefetch"/>
# <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-Championnat_de_France_de_football_2019-2020 rootpage-Championnat_de_France_de_football_2019-2020 skin-vector action-view skin-vector-search-vue"><div class="mw-page-container">
# <a class="mw-jump-link" href="#content">Aller au contenu</a>
# <div class="mw-page-container-inner">
# <input checked="" class="mw-checkbox-hack-checkbox" id="mw-sidebar-checkbox" type="checkbox"/>
# <header class="mw-header">
# <label aria-controls="mw-panel" class="mw-checkbox-hack-button mw-ui-icon mw-ui-icon-element" data-event-name="ui.sidebar" for="mw-sidebar-checkbox" id="mw-sidebar-button" role="button" tabindex="0">
# 		Afficher / masquer la barre latérale
# 	</label>
# <a class="mw-logo" href="/wiki/Wikip%C3%A9dia:Accueil_principal">
# <img alt="" aria-hidden="true" class="mw-logo-icon" height="50" src="/static/images/mobile/copyright/wikipedia.png" width="50"/>
# <span class="mw-logo-container">
# <img alt="Wikipédia" class="mw-logo-wordmark" height="18" src="/static/images/mobile/copyright/wikipedia-wordmark-fr.svg" width="119"/>
# <img alt="l'encyclopédie libre" class="mw-logo-tagline" height="13" src="/static/images/mobile/copyright/wikipedia-tagline-fr.svg" width="113"/>
# </span>
# </a>
# <div class="p-search--show-thumbnail" id="p-search" role="search">
# <h3>
# <label for="searchInput">Rechercher</label>
# </h3>
# <form action="/w/index.php" id="searchform">
# <div data-search-loc="header-moved" id="simpleSearch">
# <input accesskey="f" autocapitalize="sentences" id="searchInput" name="search" placeholder="Rechercher dans Wikipédia" title="Rechercher dans Wikipédia [f]" type="search"/>
# <input name="title" type="hidden" value="Spécial:Recherche"/>
# <input class="searchButton mw-fallbackSearchButton" id="mw-searchButton" name="fulltext" title="Rechercher les pages comportant ce texte." type="submit" value="Rechercher"/>
# <input class="searchButton" id="searchButton" name="go" title="Accédez à une page du même nom si elle existe" type="submit" value="Lire"/>
# </div>
# </form>
# </div>
# <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-personal-label" class="mw-portlet mw-portlet-personal vector-menu" id="p-personal" role="navigation">
# <h3 class="vector-menu-heading" id="p-personal-label">
# <span>Outils personnels</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li id="pt-anonuserpage">Non connecté</li><li id="pt-anontalk"><a accesskey="n" href="/wiki/Sp%C3%A9cial:Mes_discussions" title="La page de discussion pour les contributions depuis cette adresse IP [n]">Discussion</a></li><li id="pt-anoncontribs"><a accesskey="y" href="/wiki/Sp%C3%A9cial:Mes_contributions" title="Une liste des modifications effectuées depuis cette adresse IP [y]">Contributions</a></li><li id="pt-createaccount"><a href="/w/index.php?title=Sp%C3%A9cial:Cr%C3%A9er_un_compte&amp;returnto=Championnat+de+France+de+football+2019-2020" title="Nous vous encourageons à créer un compte utilisateur et vous connecter ; ce n’est cependant pas obligatoire.">Créer un compte</a></li><li id="pt-login"><a accesskey="o" href="/w/index.php?title=Sp%C3%A9cial:Connexion&amp;returnto=Championnat+de+France+de+football+2019-2020" title="Nous vous encourageons à vous connecter ; ce n’est cependant pas obligatoire. [o]">Se connecter</a></li></ul>
# </div>
# </nav>
# </header>
# <div class="mw-workspace-container">
# <div id="mw-navigation">
# <h2>Menu de navigation</h2>
# <div class="mw-sidebar" id="mw-panel">
# <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-navigation-label" class="mw-portlet mw-portlet-navigation vector-menu vector-menu-portal portal" id="p-navigation" role="navigation">
# <h3 class="vector-menu-heading" id="p-navigation-label">
# <span>Navigation</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li id="n-mainpage-description"><a accesskey="z" href="/wiki/Wikip%C3%A9dia:Accueil_principal" title="Accueil général [z]">Accueil</a></li><li id="n-thema"><a href="/wiki/Portail:Accueil">Portails thématiques</a></li><li id="n-randompage"><a accesskey="x" href="/wiki/Sp%C3%A9cial:Page_au_hasard" title="Affiche un article au hasard [x]">Article au hasard</a></li><li id="n-contact"><a href="/wiki/Wikip%C3%A9dia:Contact">Contact</a></li></ul>
# </div>
# </nav>
# <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-Contribuer-label" class="mw-portlet mw-portlet-Contribuer vector-menu vector-menu-portal portal" id="p-Contribuer" role="navigation">
# <h3 class="vector-menu-heading" id="p-Contribuer-label">
# <span>Contribuer</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li id="n-aboutwp"><a href="/wiki/Aide:D%C3%A9buter">Débuter sur Wikipédia</a></li><li id="n-help"><a href="/wiki/Aide:Accueil" title="Accès à l’aide">Aide</a></li><li id="n-portal"><a href="/wiki/Wikip%C3%A9dia:Accueil_de_la_communaut%C3%A9" title="À propos du projet, ce que vous pouvez faire, où trouver les informations">Communauté</a></li><li id="n-recentchanges"><a accesskey="r" href="/wiki/Sp%C3%A9cial:Modifications_r%C3%A9centes" title="Liste des modifications récentes sur le wiki [r]">Modifications récentes</a></li><li id="n-sitesupport"><a href="//donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_fr.wikipedia.org&amp;uselang=fr" title="Soutenez-nous">Faire un don</a></li></ul>
# </div>
# </nav>
# <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-tb-label" class="mw-portlet mw-portlet-tb vector-menu vector-menu-portal portal" id="p-tb" role="navigation">
# <h3 class="vector-menu-heading" id="p-tb-label">
# <span>Outils</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li id="t-whatlinkshere"><a accesskey="j" href="/wiki/Sp%C3%A9cial:Pages_li%C3%A9es/Championnat_de_France_de_football_2019-2020" title="Liste des pages liées qui pointent sur celle-ci [j]">Pages liées</a></li><li id="t-recentchangeslinked"><a accesskey="k" href="/wiki/Sp%C3%A9cial:Suivi_des_liens/Championnat_de_France_de_football_2019-2020" rel="nofollow" title="Liste des modifications récentes des pages appelées par celle-ci [k]">Suivi des pages liées</a></li><li id="t-upload"><a accesskey="u" href="/wiki/Aide:Importer_un_fichier" title="Importer des fichiers [u]">Téléverser un fichier</a></li><li id="t-specialpages"><a accesskey="q" href="/wiki/Sp%C3%A9cial:Pages_sp%C3%A9ciales" title="Liste de toutes les pages spéciales [q]">Pages spéciales</a></li><li id="t-permalink"><a href="/w/index.php?title=Championnat_de_France_de_football_2019-2020&amp;oldid=181084403" title="Adresse permanente de cette version de la page">Lien permanent</a></li><li id="t-info"><a href="/w/index.php?title=Championnat_de_France_de_football_2019-2020&amp;action=info" title="Plus d’informations sur cette page">Informations sur la page</a></li><li id="t-cite"><a href="/w/index.php?title=Sp%C3%A9cial:Citer&amp;page=Championnat_de_France_de_football_2019-2020&amp;id=181084403&amp;wpFormIdentifier=titleform" title="Informations sur la manière de citer cette page">Citer cette page</a></li><li id="t-wikibase"><a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q61862323" title="Lien vers l’élément dans le dépôt de données connecté [g]">Élément Wikidata</a></li></ul>
# </div>
# </nav>
# <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-coll-print_export-label" class="mw-portlet mw-portlet-coll-print_export vector-menu vector-menu-portal portal" id="p-coll-print_export" role="navigation">
# <h3 class="vector-menu-heading" id="p-coll-print_export-label">
# <span>Imprimer / exporter</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li id="coll-create_a_book"><a href="/w/index.php?title=Sp%C3%A9cial:Livre&amp;bookcmd=book_creator&amp;referer=Championnat+de+France+de+football+2019-2020">Créer un livre</a></li><li id="coll-download-as-rl"><a href="/w/index.php?title=Sp%C3%A9cial:DownloadAsPdf&amp;page=Championnat_de_France_de_football_2019-2020&amp;action=show-download-screen">Télécharger comme PDF</a></li><li id="t-print"><a accesskey="p" href="/w/index.php?title=Championnat_de_France_de_football_2019-2020&amp;printable=yes" title="Version imprimable de cette page [p]">Version imprimable</a></li></ul>
# </div>
# </nav>
# <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-wikibase-otherprojects-label" class="mw-portlet mw-portlet-wikibase-otherprojects vector-menu vector-menu-portal portal" id="p-wikibase-otherprojects" role="navigation">
# <h3 class="vector-menu-heading" id="p-wikibase-otherprojects-label">
# <span>Dans d’autres projets</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="wb-otherproject-link wb-otherproject-commons"><a href="https://commons.wikimedia.org/wiki/Category:Ligue_1_season_2019-2020" hreflang="en">Wikimedia Commons</a></li><li class="wb-otherproject-link wb-otherproject-wikinews"><a href="https://fr.wikinews.org/wiki/Cat%C3%A9gorie:Championnat_de_France_2019-2020_de_football_de_Ligue_1" hreflang="fr">Wikinews</a></li></ul>
# </div>
# </nav>
# <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-lang-label" class="mw-portlet mw-portlet-lang vector-menu vector-menu-portal portal" id="p-lang" role="navigation">
# <h3 class="vector-menu-heading" id="p-lang-label">
# <span>Dans d’autres langues</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="interlanguage-link interwiki-ar"><a class="interlanguage-link-target" href="https://ar.wikipedia.org/wiki/%D8%A7%D9%84%D8%AF%D9%88%D8%B1%D9%8A_%D8%A7%D9%84%D9%81%D8%B1%D9%86%D8%B3%D9%8A_2019%E2%80%9320" hreflang="ar" lang="ar" title="الدوري الفرنسي 2019–20 — arabe">العربية</a></li><li class="interlanguage-link interwiki-bn"><a class="interlanguage-link-target" href="https://bn.wikipedia.org/wiki/%E0%A7%A8%E0%A7%A6%E0%A7%A7%E0%A7%AF%E2%80%93%E0%A7%A8%E0%A7%A6_%E0%A6%B2%E0%A7%80%E0%A6%97_%E0%A7%A7" hreflang="bn" lang="bn" title="২০১৯–২০ লীগ ১ — bengali">বাংলা</a></li><li class="interlanguage-link interwiki-de"><a class="interlanguage-link-target" href="https://de.wikipedia.org/wiki/Ligue_1_2019/20" hreflang="de" lang="de" title="Ligue 1 2019/20 — allemand">Deutsch</a></li><li class="interlanguage-link interwiki-en"><a class="interlanguage-link-target" href="https://en.wikipedia.org/wiki/2019%E2%80%9320_Ligue_1" hreflang="en" lang="en" title="2019–20 Ligue 1 — anglais">English</a></li><li class="interlanguage-link interwiki-es"><a class="interlanguage-link-target" href="https://es.wikipedia.org/wiki/Ligue_1_2019-20" hreflang="es" lang="es" title="Ligue 1 2019-20 — espagnol">Español</a></li><li class="interlanguage-link interwiki-fa"><a class="interlanguage-link-target" href="https://fa.wikipedia.org/wiki/%D9%84%DB%8C%DA%AF_%DB%B1_%DB%B2%DB%B0%E2%80%93%DB%B2%DB%B0%DB%B1%DB%B9" hreflang="fa" lang="fa" title="لیگ ۱ ۲۰–۲۰۱۹ — persan">فارسی</a></li><li class="interlanguage-link interwiki-he"><a class="interlanguage-link-target" href="https://he.wikipedia.org/wiki/%D7%A2%D7%95%D7%A0%D7%AA_2019/2020_%D7%91%D7%9C%D7%99%D7%92_1" hreflang="he" lang="he" title="עונת 2019/2020 בליג 1 — hébreu">עברית</a></li><li class="interlanguage-link interwiki-hu"><a class="interlanguage-link-target" href="https://hu.wikipedia.org/wiki/2019%E2%80%932020-as_francia_labdar%C3%BAg%C3%B3-bajnoks%C3%A1g_(els%C5%91_oszt%C3%A1ly)" hreflang="hu" lang="hu" title="2019–2020-as francia labdarúgó-bajnokság (első osztály) — hongrois">Magyar</a></li><li class="interlanguage-link interwiki-it"><a class="interlanguage-link-target" href="https://it.wikipedia.org/wiki/Ligue_1_2019-2020" hreflang="it" lang="it" title="Ligue 1 2019-2020 — italien">Italiano</a></li><li class="interlanguage-link interwiki-ja"><a class="interlanguage-link-target" href="https://ja.wikipedia.org/wiki/%E3%83%AA%E3%83%BC%E3%82%B0%E3%83%BB%E3%82%A2%E3%83%B32019-2020" hreflang="ja" lang="ja" title="リーグ・アン2019-2020 — japonais">日本語</a></li><li class="interlanguage-link interwiki-kk"><a class="interlanguage-link-target" href="https://kk.wikipedia.org/wiki/%D0%A4%D1%83%D1%82%D0%B1%D0%BE%D0%BB%D0%B4%D0%B0%D0%BD_%D0%A4%D1%80%D0%B0%D0%BD%D1%86%D0%B8%D1%8F_%D1%87%D0%B5%D0%BC%D0%BF%D0%B8%D0%BE%D0%BD%D0%B0%D1%82%D1%8B_2019/20" hreflang="kk" lang="kk" title="Футболдан Франция чемпионаты 2019/20 — kazakh">Қазақша</a></li><li class="interlanguage-link interwiki-ko"><a class="interlanguage-link-target" href="https://ko.wikipedia.org/wiki/%EB%A6%AC%EA%B7%B8_1_2019-20" hreflang="ko" lang="ko" title="리그 1 2019-20 — coréen">한국어</a></li><li class="interlanguage-link interwiki-lv"><a class="interlanguage-link-target" href="https://lv.wikipedia.org/wiki/2019.%E2%80%942020._gada_Francijas_futbola_1._l%C4%ABgas_sezona" hreflang="lv" lang="lv" title="2019.—2020. gada Francijas futbola 1. līgas sezona — letton">Latviešu</a></li><li class="interlanguage-link interwiki-nl"><a class="interlanguage-link-target" href="https://nl.wikipedia.org/wiki/Ligue_1_2019/20" hreflang="nl" lang="nl" title="Ligue 1 2019/20 — néerlandais">Nederlands</a></li><li class="interlanguage-link interwiki-no"><a class="interlanguage-link-target" href="https://no.wikipedia.org/wiki/Ligue_1_2019%E2%80%932020" hreflang="nb" lang="nb" title="Ligue 1 2019–2020 — norvégien bokmål">Norsk bokmål</a></li><li class="interlanguage-link interwiki-pl"><a class="interlanguage-link-target" href="https://pl.wikipedia.org ...
# <div class="after-portlet after-portlet-lang"><span class="wb-langlinks-edit wb-langlinks-link"><a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q61862323#sitelinks-wikipedia" title="Modifier les liens interlangues">Modifier les liens</a></span></div>
# </div>
# </nav>
# </div>
# <div id="mw-head">
# <div class="mw-article-toolbar-container">
# <div id="left-navigation">
# <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-namespaces-label" class="mw-portlet mw-portlet-namespaces vector-menu vector-menu-tabs" id="p-namespaces" role="navigation">
# <h3 class="vector-menu-heading" id="p-namespaces-label">
# <span>Espaces de noms</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="selected" id="ca-nstab-main"><a accesskey="c" href="/wiki/Championnat_de_France_de_football_2019-2020" title="Voir le contenu de la page [c]">Article</a></li><li id="ca-talk"><a accesskey="t" href="/wiki/Discussion:Championnat_de_France_de_football_2019-2020" rel="discussion" title="Discussion au sujet de cette page de contenu [t]">Discussion</a></li></ul>
# </div>
# </nav>
# <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-variants-label" class="mw-portlet mw-portlet-variants emptyPortlet vector-menu vector-menu-dropdown" id="p-variants" role="navigation">
# <input aria-labelledby="p-variants-label" class="vector-menu-checkbox" type="checkbox"/>
# <h3 class="vector-menu-heading" id="p-variants-label">
# <span>Variantes</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"></ul>
# </div>
# </nav>
# </div>
# <div id="right-navigation">
# <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-views-label" class="mw-portlet mw-portlet-views vector-menu vector-menu-tabs" id="p-views" role="navigation">
# <h3 class="vector-menu-heading" id="p-views-label">
# <span>Affichages</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="selected" id="ca-view"><a href="/wiki/Championnat_de_France_de_football_2019-2020">Lire</a></li><li id="ca-ve-edit"><a accesskey="v" href="/w/index.php?title=Championnat_de_France_de_football_2019-2020&amp;veaction=edit" title="Modifier cette page [v]">Modifier</a></li><li class="collapsible" id="ca-edit"><a accesskey="e" href="/w/index.php?title=Championnat_de_France_de_football_2019-2020&amp;action=edit" title="Vous pouvez modifier cette page ! [e]">Modifier le code</a></li><li id="ca-history"><a accesskey="h" href="/w/index.php?title=Championnat_de_France_de_football_2019-2020&amp;action=history" title="Historique des versions de cette page [h]">Voir l’historique</a></li></ul>
# </div>
# </nav>
# <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <nav aria-labelledby="p-cactions-label" class="mw-portlet mw-portlet-cactions emptyPortlet vector-menu vector-menu-dropdown" id="p-cactions" role="navigation">
# <input aria-labelledby="p-cactions-label" class="vector-menu-checkbox" type="checkbox"/>
# <h3 class="vector-menu-heading" id="p-cactions-label">
# <span>Plus</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"></ul>
# </div>
# </nav>
# </div>
# </div>
# </div>
# </div>
# <div class="mw-content-container">
# <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
# <main class="mw-body" id="content" role="main">
# <a id="top"></a>
# <div class="mw-body-content" id="siteNotice"><!-- CentralNotice --></div>
# <div class="mw-indicators mw-body-content">
# </div>
# <h1 class="firstHeading" id="firstHeading">Championnat de France de football 2019-2020</h1>
# <div class="mw-body-content" id="bodyContent">
# <div class="noprint" id="siteSub">Un article de Wikipédia, l'encyclopédie libre.</div>
# <div id="contentSub"></div>
# <div id="contentSub2"></div>
# <div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="fr"><div class="mw-parser-output"><div class="infobox_v3">
# <div class="entete icon football" style="background-color: #99cc99; color: #000000;"><style data-mw-deduplicate="TemplateStyles:r160408203">.mw-parser-output .entete.football{background-image:url("//upload.wikimedia.org/wikipedia/commons/f/f8/Infobox_Football_pictogram.png")}</style>
# <div>Ligue 1 2019-2020</div>
# </div><div class="images"><a class="image" href="/w/index.php?title=Fichier:Ligue_1_Conforama.svg&amp;lang=fr"><img alt="Logo du championnat de France de football" data-file-height="62" data-file-width="45" decoding="async" height="179" src="//upload.wikimedia.org/wikipedia/fr/thumb/1/14/Ligue_1_Conforama.svg/langfr-130px-Ligue_1_Conforama.svg.png" srcset="//upload.wikimedia.org/wikipedia/fr/thumb/1/14/Ligue_1_Conforama.svg/langfr-195px-Ligue_1_Conforama.svg.png 1.5x, //upload.wikimedia.org/wikipedia/fr/thumb/1/14/Ligue_1_Conforama.svg/langfr-260px-Ligue_1_Conforama.svg.png 2x" width="130"/></a>
# </div><table><caption style="background:#99cc99;color:#000000;">Généralités</caption><tbody><tr>
# <th scope="row" style="width:10.5em;">Sport</th>
# <td>
# <a href="/wiki/Football" title="Football">Football</a></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Organisateur(s)</th>
# <td>
# <a href="/wiki/Ligue_de_football_professionnel" title="Ligue de football professionnel">LFP</a></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Édition</th>
# <td>
# <abbr class="abbr" title="Quatre-vingt-deuxième (huitante-deuxième / octante-deuxième)">82<sup>e</sup></abbr></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Lieu(x)</th>
# <td>
# <span class="datasortkey" data-sort-value="France"><span class="flagicon"><a class="image" href="/wiki/Fichier:Flag_of_France.svg" title="Drapeau de la France"><img alt="Drapeau de la France" class="noviewer thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Flag_of_France.svg/20px-Flag_of_France.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Flag_of_France.svg/30px-Flag_of_France.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Flag_of_France.svg/40px-Flag_of_France.svg.png 2x" width="20"/></a> </span><a href="/wiki/France" title="France">France</a></span> et <br/><span class="datasortkey" data-sort-value="Monaco"><span class="flagicon"><a class="image" href="/wiki/Fichier:Flag_of_Monaco.svg" title="Drapeau de Monaco"><img alt="Drapeau de Monaco" class="noviewer thumbborder" data-file-height="800" data-file-width="1000" decoding="async" height="16" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Flag_of_Monaco.svg/20px-Flag_of_Monaco.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Flag_of_Monaco.svg/30px-Flag_of_Monaco.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Flag_of_Monaco.svg/40px-Flag_of_Monaco.svg.png 2x" width="20"/></a> </span><a href="/wiki/Monaco" title="Monaco">Monaco</a></span></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Date</th>
# <td>
# Du <time class="nowrap date-lien" data-sort-value="2019-08-09" datetime="2019-08-09"><a href="/wiki/9_ao%C3%BBt_en_sport" title="9 août en sport">9</a> <a class="mw-redirect" href="/wiki/Ao%C3%BBt_2019_en_sport" title="Août 2019 en sport">août</a> <a href="/wiki/2019_en_football" title="2019 en football">2019</a></time><br/>au <time class="nowrap date-lien" data-sort-value="2020-03-08" datetime="2020-03-08"><a href="/wiki/8_mars_en_sport" title="8 mars en sport">8 mars</a> <a href="/wiki/2020_en_football" title="2020 en football">2020</a></time> <small>(arrêt définitif)</small></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Participants</th>
# <td>
# 20 équipes</td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Matchs joués</th>
# <td>
# 279</td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Site web officiel</th>
# <td>
# <a class="external text" href="https://www.ligue1.fr/" rel="nofollow">Site officiel</a></td>
# </tr></tbody></table><table><caption style="background:#99cc99;color:#000000;">Hiérarchie</caption><tbody><tr>
# <th scope="row" style="width:10.5em;">Hiérarchie</th>
# <td>
# <abbr class="abbr" title="Premier">1<sup>er</sup></abbr> échelon</td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Niveau inférieur</th>
# <td>
# <a class="mw-redirect" href="/wiki/Championnat_de_France_de_football_de_Ligue_2_2019-2020" title="Championnat de France de football de Ligue 2 2019-2020">Ligue 2 2019-2020</a></td>
# </tr></tbody></table><p class="mw-empty-elt">
# </p><table><caption style="background:#99cc99;color:#000000;">Palmarès</caption>
# <tbody><tr>
# <th scope="row" style="width:10.5em;">Tenant du titre</th>
# <td>
# <a href="/wiki/Paris_Saint-Germain_Football_Club" title="Paris Saint-Germain Football Club">Paris Saint-Germain</a> (8)</td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Promu(s) en début de saison</th>
# <td>
# <a href="/wiki/Football_Club_de_Metz" title="Football Club de Metz">FC Metz</a><br/><a href="/wiki/Stade_brestois_29" title="Stade brestois 29">Stade brestois 29</a></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Vainqueur</th>
# <td>
# <b><a href="/wiki/Paris_Saint-Germain_Football_Club" title="Paris Saint-Germain Football Club">Paris Saint-Germain</a> (9)</b></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Deuxième</th>
# <td>
# <a href="/wiki/Olympique_de_Marseille" title="Olympique de Marseille">Olympique de Marseille</a></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Troisième</th>
# <td>
# <a class="mw-redirect" href="/wiki/Stade_rennais_football_club" title="Stade rennais football club">Stade rennais FC</a></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Relégué(s)</th>
# <td>
# <a href="/wiki/Amiens_Sporting_Club" title="Amiens Sporting Club">Amiens SC</a><br/><a href="/wiki/Toulouse_Football_Club" title="Toulouse Football Club">Toulouse FC</a></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Buts</th>
# <td>
# 702 <small>(2,51 buts par match)</small></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;"><img alt="Averti" data-file-height="260" data-file-width="200" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Yellow_card.svg/10px-Yellow_card.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Yellow_card.svg/15px-Yellow_card.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Yellow_card.svg/20px-Yellow_card.svg.png 2x" title="Averti" width="10"/> Cartons jaunes</th>
# <td>
# 1029 <small>(3,68 par match)</small></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;"><a class="image" href="/wiki/Fichier:Red_card.svg"><img alt="Red card.svg" data-file-height="260" data-file-width="200" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/e7/Red_card.svg/10px-Red_card.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/e7/Red_card.svg/15px-Red_card.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/e/e7/Red_card.svg/20px-Red_card.svg.png 2x" width="10"/></a> Cartons rouges</th>
# <td>
# 70 <small>(0,25 par match)</small></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Meilleur joueur</th>
# <td>
# Non attribué</td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Meilleur(s) buteur(s)</th>
# <td>
# <span class="flagicon"><a class="image" href="/wiki/Fichier:Flag_of_France.svg" title="Drapeau : France"><img alt="Drapeau : France" class="noviewer thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Flag_of_France.svg/20px-Flag_of_France.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Flag_of_France.svg/30px-Flag_of_France.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Flag_of_France.svg/40px-Flag_of_France.svg.png 2x" width="20"/></a></span> <a href="/wiki/Kylian_Mbapp%C3%A9" title="Kylian Mbappé">Kylian Mbappé</a> (18)</td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Meilleur(s) passeur(s)</th>
# <td>
# <span class="flagicon"><a class="image" href="/wiki/Fichier:Flag_of_Argentina.svg" title="Drapeau : Argentine"><img alt="Drapeau : Argentine" class="noviewer thumbborder" data-file-height="500" data-file-width="800" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/20px-Flag_of_Argentina.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/30px-Flag_of_Argentina.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/40px-Flag_of_Argentina.svg.png 2x" width="20"/></a></span> <a href="/wiki/%C3%81ngel_Di_Mar%C3%ADa" title="Ángel Di María">Ángel Di María</a> (14)</td>
# </tr>
# </tbody></table><p class="bloc" style="background:#99cc99; color:#000000;"><a href="/wiki/Championnat_de_France_de_football" title="Championnat de France de football">Navigation</a></p>
# <p class="overflow nav navigation-not-searchable" style=""><span class="prev"><a href="/wiki/Championnat_de_France_de_football_2018-2019" title="Championnat de France de football 2018-2019">Ligue 1 2018-2019</a></span> <span class="next"><a href="/wiki/Championnat_de_France_de_football_2020-2021" title="Championnat de France de football 2020-2021">Ligue 1 2020-2021</a></span></p>
# <p class="navbar bordered noprint" style="border-color:#99cc99; border-width:2px;"><span class="plainlinks navigation-not-searchable"><a class="external text" href="https://fr.wikipedia.org/w/index.php?title=Championnat_de_France_de_football_2019-2020&amp;action=edit">modifier</a></span> <a href="/wiki/Mod%C3%A8le:Infobox_Comp%C3%A9tition_sportive" title="Consultez la documentation du modèle"><img alt="Consultez la documentation du modèle" data-file-height="512" data-file-width="512" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/38/Info_Simple.svg/12px-Info_Simple.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/38/Info_Simple.svg/18px-Info_Simple.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/38/Info_Simple.svg/24px-Info_Simple.svg.png 2x" width="12"/></a></p></div>
# <p>La <b>saison 2019-2020 de Ligue 1</b> est la <abbr class="abbr" title="Quatre-vingt-deuxième (huitante-deuxième / octante-deuxième)">82<sup>e</sup></abbr> édition du <a href="/wiki/Championnat_de_France_de_football" title="Championnat de France de football">championnat de France de football</a> et la <abbr class="abbr" title="Dix-huitième">18<sup>e</sup></abbr> sous l'appellation « <span class="nowrap">Ligue 1</span> », la <abbr class="abbr" title="Troisième">3<sup>e</sup></abbr> et dernière sous l'appellation Ligue 1 Conforama. La saison a débuté le <time class="nowrap date-lien" data-sort-value="2019-08-09" datetime="2019-08-09"><a href="/wiki/9_ao%C3%BBt_en_sport" title="9 août en sport">9</a> <a class="mw-redirect" href="/wiki/Ao%C3%BBt_2019_en_sport" title="Août 2019 en sport">août</a> <a href="/wiki/2019_en_football" title="2019 en football">2019</a></time> et s'est achevée de manière prématurée le 8 mars 2020 à la suite de la <a href="/wiki/Pand%C3%A9mie_de_Covid-19_en_France" title="Pandémie de Covid-19 en France">pandémie de Covid-19 en France</a><sup class="reference" id="cite_ref-1"><a href="#cite_note-1"><span class="cite_crochet">[</span>1<span class="cite_crochet">]</span></a></sup>.
# </p><p>Les équipes promues de deuxième division sont le <a href="/wiki/Football_Club_de_Metz" title="Football Club de Metz">FC Metz</a> et le <a href="/wiki/Stade_brestois_29" title="Stade brestois 29">Stade brestois 29</a>.
# </p><p>Le 30 avril, la LFP vote la fin officielle du championnat et détermine le classement final en prenant en compte un indice de performance (ratio) selon le nombre de points marqués sur tous les matchs joués<sup class="reference" id="cite_ref-covid_2-0"><a href="#cite_note-covid-2"><span class="cite_crochet">[</span>2<span class="cite_crochet">]</span></a></sup>. Le <a href="/wiki/Paris_Saint-Germain_Football_Club" title="Paris Saint-Germain Football Club">Paris Saint-Germain</a> est déclaré champion de France, les clubs relégués en <a class="mw-redirect" href="/wiki/Championnat_de_France_de_football_de_Ligue_2" title="Championnat de France de football de Ligue 2">Ligue 2</a> sont l'<a href="/wiki/Amiens_Sporting_Club" title="Amiens Sporting Club">Amiens SC</a> et le <a href="/wiki/Toulouse_Football_Club" title="Toulouse Football Club">Toulouse FC</a><sup class="reference" id="cite_ref-covid_2-1"><a href="#cite_note-covid-2"><span class="cite_crochet">[</span>2<span class="cite_crochet">]</span></a></sup>.
# </p>
# <div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation"><input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"/><div class="toctitle" dir="ltr" lang="fr"><h2 id="mw-toc-heading">Sommaire</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#Participants"><span class="tocnumber">1</span> <span class="toctext">Participants</span></a>
# <ul>
# <li class="toclevel-2 tocsection-2"><a href="#Changements_d'entraîneur"><span class="tocnumber">1.1</span> <span class="toctext">Changements d'entraîneur</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-3"><a href="#Compétition"><span class="tocnumber">2</span> <span class="toctext">Compétition</span></a>
# <ul>
# <li class="toclevel-2 tocsection-4"><a href="#Règlement"><span class="tocnumber">2.1</span> <span class="toctext">Règlement</span></a></li>
# <li class="toclevel-2 tocsection-5"><a href="#Classement"><span class="tocnumber">2.2</span> <span class="toctext">Classement</span></a></li>
# <li class="toclevel-2 tocsection-6"><a href="#Leader_par_journée"><span class="tocnumber">2.3</span> <span class="toctext">Leader par journée</span></a></li>
# <li class="toclevel-2 tocsection-7"><a href="#Lanterne_rouge_par_journée"><span class="tocnumber">2.4</span> <span class="toctext">Lanterne rouge par journée</span></a></li>
# <li class="toclevel-2 tocsection-8"><a href="#Matchs"><span class="tocnumber">2.5</span> <span class="toctext">Matchs</span></a>
# <ul>
# <li class="toclevel-3 tocsection-9"><a href="#Barrage_de_relégation"><span class="tocnumber">2.5.1</span> <span class="toctext">Barrage de relégation</span></a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-10"><a href="#Statistiques"><span class="tocnumber">3</span> <span class="toctext">Statistiques</span></a>
# <ul>
# <li class="toclevel-2 tocsection-11"><a href="#Domicile_et_extérieur"><span class="tocnumber">3.1</span> <span class="toctext">Domicile et extérieur</span></a></li>
# <li class="toclevel-2 tocsection-12"><a href="#Évolution_du_classement"><span class="tocnumber">3.2</span> <span class="toctext">Évolution du classement</span></a></li>
# <li class="toclevel-2 tocsection-13"><a href="#Buts_marqués_par_journée"><span class="tocnumber">3.3</span> <span class="toctext">Buts marqués par journée</span></a></li>
# <li class="toclevel-2 tocsection-14"><a href="#Classement_des_buteurs"><span class="tocnumber">3.4</span> <span class="toctext">Classement des buteurs</span></a>
# <ul>
# <li class="toclevel-3 tocsection-15"><a href="#Leader_par_journée_2"><span class="tocnumber">3.4.1</span> <span class="toctext">Leader par journée</span></a></li>
# </ul>
# </li>
# <li class="toclevel-2 tocsection-16"><a href="#Classement_des_passeurs"><span class="tocnumber">3.5</span> <span class="toctext">Classement des passeurs</span></a>
# <ul>
# <li class="toclevel-3 tocsection-17"><a href="#Leader_par_journée_3"><span class="tocnumber">3.5.1</span> <span class="toctext">Leader par journée</span></a></li>
# </ul>
# </li>
# <li class="toclevel-2 tocsection-18"><a href="#Affluence"><span class="tocnumber">3.6</span> <span class="toctext">Affluence</span></a>
# <ul>
# <li class="toclevel-3 tocsection-19"><a href="#Meilleures_affluences_de_la_saison"><span class="tocnumber">3.6.1</span> <span class="toctext">Meilleures affluences de la saison</span></a></li>
# <li class="toclevel-3 tocsection-20"><a href="#Affluences_par_journée"><span class="tocnumber">3.6.2</span> <span class="toctext">Affluences par journée</span></a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-21"><a href="#Bilan_de_la_saison"><span class="tocnumber">4</span> <span class="toctext">Bilan de la saison</span></a></li>
# <li class="toclevel-1 tocsection-22"><a href="#Trophée_UNFP"><span class="tocnumber">5</span> <span class="toctext">Trophée UNFP</span></a></li>
# <li class="toclevel-1 tocsection-23"><a href="#Parcours_en_Coupes_d'Europe"><span class="tocnumber">6</span> <span class="toctext">Parcours en Coupes d'Europe</span></a></li>
# <li class="toclevel-1 tocsection-24"><a href="#Perturbations_lors_du_championnat"><span class="tocnumber">7</span> <span class="toctext">Perturbations lors du championnat</span></a>
# <ul>
# <li class="toclevel-2 tocsection-25"><a href="#Controverse_au_sujet_de_l'homophobie"><span class="tocnumber">7.1</span> <span class="toctext">Controverse au sujet de l'homophobie</span></a></li>
# <li class="toclevel-2 tocsection-26"><a href="#Matchs_repoussés"><span class="tocnumber">7.2</span> <span class="toctext">Matchs repoussés</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-27"><a href="#Arrêt_subit_de_la_compétition"><span class="tocnumber">8</span> <span class="toctext">Arrêt subit de la compétition</span></a>
# <ul>
# <li class="toclevel-2 tocsection-28"><a href="#Chronologie"><span class="tocnumber">8.1</span> <span class="toctext">Chronologie</span></a></li>
# <li class="toclevel-2 tocsection-29"><a href="#Méthode_de_classement"><span class="tocnumber">8.2</span> <span class="toctext">Méthode de classement</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-30"><a href="#Notes_et_références"><span class="tocnumber">9</span> <span class="toctext">Notes et références</span></a></li>
# <li class="toclevel-1 tocsection-31"><a href="#Voir_aussi"><span class="tocnumber">10</span> <span class="toctext">Voir aussi</span></a></li>
# </ul>
# </div>
# <h2><span class="mw-headline" id="Participants">Participants</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a class="mw-editsection-visualeditor" href="/w/index.php?title=Championnat_de_France_de_football_2019-2020&amp;veaction=edit&amp;section=1" title="Modifier la section : Participants">modifier</a><span class="mw-editsection-divider"> | </span><a href="/w/index.php?title=Championnat_de_France_de_football_2019-2020&amp;action=edit&amp;section=1" title="Modifier la section : Participants">modifier le code</a><span class="mw-editsection-bracket">]</span></span></h2>
# <div class="tright" style="margin-bottom: .5em; border-style: solid; border-color: transparent; width: auto;"><table align="center" cellspacing="0" style="width:0px;"><tbody><tr><td style="border:none;"><div class="thumbinner"><div class="thumbimage">
# <table class="DebutCarte" style="width:auto; margin:0; border:none; border-spacing:0; padding:0; text-align:center; font-size:72%; line-height:1.1em;">
# <tbody><tr><td style="border:none; padding:0"><div style="position:relative;;"><a class="image" href="/wiki/Fichier:France_location_map-Regions-2016.svg"><img alt="France location map-Regions-2016.svg" data-file-height="1922" data-file-width="2000" decoding="async" height="288" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/France_location_map-Regions-2016.svg/300px-France_location_map-Regions-2016.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/France_location_map-Regions-2016.svg/450px-France_location_map-Regions-2016.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b1/France_location_map-Regions-2016.svg/600px-France_location_map-Regions-2016.svg.png 2x" width="300"/></a>
# <div style="position:absolute;top:25.175142857144%;left:51.596329113919%;width:0px;height:0px;margin:0;padding:0;line-height:0px;background-color:transparent;"><div style="position:relative;top:-8px;left:-8px;width:16px;height:16px;background-color:transparent;"><img alt="Localisation de la ville" class="noviewer" data-file-height="16" data-file-width="16" decoding="async" height="16" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/City_locator_4.svg/16px-City_locator_4.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/City_locator_4.svg/24px-City_locator_4.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/21/City_locator_4.svg/32px-City_locator_4.svg.png 2x" width="16"/></div><div style="position:relative;top:-17px;"><div style="font-size:90%;position:relative;top:-0.80em;left:-12.6em;text-align:right;width:12em;line-height:1.2em;"><span class="toponyme"><b><a href="/wiki/Paris_Saint-Germain_Football_Club" title="Paris Saint-Germain Football Club">Paris SG</a></b></span></div></div></div>
# <div style="position:absolute;top:8.2928571428576%;left:56.058544303792%;width:0px;height:0px;margin:0;padding:0;line-height:0px;background-color:transparent;"><div style="position:relative;top:-8px;left:-8px;width:16px;height:16px;background-color:transparent;"><img alt="Localisation de la ville" class="noviewer" data-file-height="16" data-file-width="16" decoding="async" height="16" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/City_locator_4.svg/16px-City_locator_4.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/City_locator_4.svg/24px-City_locator_4.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/21/City_locator_4.svg/32px-City_locator_4.svg.png 2x" width="16"/></div><div style="position:relative;top:-17px;"><div style="font-size:90%;position:relative;top:-1.65em;left: 0.5em;text-align:left;width:12em;line-height:1.2em;"><span class="toponyme"><b><a href="/wiki/LOSC_Lille" title="LOSC Lille">LOSC Lille</a></b></span></div></div></div>
# <div style="position:absolute;top:54.628190476193%;left:67.314240506322%;width:0px;height:0px;margin:0;padding:0;line-height:0px;background-color:transparent;"><div style="position:relative;top:-8px;left:-8px;width:16px;height:16px;background-color:transparent;"><img alt="Localisation de la ville" class="noviewer" data-file-height="16" data-file-width="16" decoding="async" height="16" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/City_locator_4.svg/16px-City_locator_4.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/City_locator_4.svg/24px-City_locator_4.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/21/City_locator_4.svg/32px-City_locator_4.svg.png 2x" width="16"/></div><div style="position:relative;top:-17px;"><div style="font-size:90%;position:relative;top:-1.75em;left: -6em;text-align:center;width:12em;line-height:1.2em;"><span class="toponyme"><b><a href="/wiki/Olympique_lyonnais" title="Olympique lyonnais">Olympique lyonnais</a></b></span></div></div></div>
# <div style="position:absolute;top:57.717238095241%;left:64.475759493664%;width:0px;height:0px;margin:0;padding:0;line-height:0px;background-color:transparent;"><div style="position:relative;top:-8px;left:-8px;width:16px;height:16px;background-color:transparent;"><img alt="Localisation de la ville" class="noviewer" data-file-height="16" data-file-width="16" decoding="async" height="16" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/City_locator_4.svg/16px-City_locator_4.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/21/City_locator_4.svg/24px-City_locator_4.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/21/City_locator_4.svg/32px-City_locator_4.svg.png 2x" width="16"/></div><div style="position:relative;top:-17px;"><div style="font-size:90%;position:relative;top: 0.00em;left: -6em;text-align:center;width:12em;line-height:1.2em;"><span class="toponyme"><b><a href="/wiki/Association_sportive_de_Saint-%C3%89tienne" title="Association sportive de Saint-Étienne">AS Saint-Étienne</a></b></span></div></div></div>
# ...
# </tr> <tr>
# <th class="navbox-group" style="background:#B3D9B3; vertical-align:middle; text-align:center">Distinctions</th>
# <td class="navbox-list navbox-even" style="text-align:left;; background:#E6F2E6;"><link href="mw-data:TemplateStyles:r151529978" rel="mw-deduplicated-inline-style"/><span class="nowrap"><span style="color:#808080">Trophées UNFP 2020 <small>(édition annulée)</small></span></span></td>
# </tr> </tbody></table>
# </div>
# <ul class="bandeau-portail" id="bandeau-portail"><li><span class="bandeau-portail-element"><span class="bandeau-portail-icone"><a href="/wiki/Portail:Football" title="Portail du football"><img alt="icône décorative" class="noviewer" data-file-height="250" data-file-width="250" decoding="async" height="24" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/0b/Soccer.svg/24px-Soccer.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/0b/Soccer.svg/36px-Soccer.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/0b/Soccer.svg/48px-Soccer.svg.png 2x" width="24"/></a></span> <span class="bandeau-portail-texte"><a href="/wiki/Portail:Football" title="Portail:Football">Portail du football</a></span> </span></li> <li><span class="bandeau-portail-element"><span class="bandeau-portail-icone"><a href="/wiki/Portail:France" title="Portail de la France"><img alt="icône décorative" class="noviewer thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="22" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Flag_of_France.svg/33px-Flag_of_France.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Flag_of_France.svg/50px-Flag_of_France.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Flag_of_France.svg/66px-Flag_of_France.svg.png 2x" width="33"/></a></span> <span class="bandeau-portail-texte"><a href="/wiki/Portail:France" title="Portail:France">Portail de la France</a></span> </span></li> <li><span class="bandeau-portail-element"><span class="bandeau-portail-icone"><a href="/wiki/Portail:Monaco" title="Portail de Monaco"><img alt="icône décorative" class="noviewer thumbborder" data-file-height="800" data-file-width="1000" decoding="async" height="22" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Flag_of_Monaco.svg/28px-Flag_of_Monaco.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Flag_of_Monaco.svg/41px-Flag_of_Monaco.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Flag_of_Monaco.svg/55px-Flag_of_Monaco.svg.png 2x" width="28"/></a></span> <span class="bandeau-portail-texte"><a href="/wiki/Portail:Monaco" title="Portail:Monaco">Portail de Monaco</a></span> </span></li> <li><span class="bandeau-portail-element"><span class="bandeau-portail-icone"><a href="/wiki/Portail:Ann%C3%A9es_2010" title="Portail des années 2010"><img alt="icône décorative" class="noviewer" data-file-height="1686" data-file-width="928" decoding="async" height="24" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/08/Nokia_Lumia_1020_Front.svg/13px-Nokia_Lumia_1020_Front.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/08/Nokia_Lumia_1020_Front.svg/20px-Nokia_Lumia_1020_Front.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/0/08/Nokia_Lumia_1020_Front.svg/26px-Nokia_Lumia_1020_Front.svg.png 2x" width="13"/></a></span> <span class="bandeau-portail-texte"><a href="/wiki/Portail:Ann%C3%A9es_2010" title="Portail:Années 2010">Portail des années 2010</a></span> </span></li> <li><span class="bandeau-portail-element"><span class="bandeau-portail-icone"><a href="/wiki/Portail:Ann%C3%A9es_2020" title="Portail des années 2020"><img alt="icône décorative" class="noviewer" data-file-height="600" data-file-width="750" decoding="async" height="24" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fd/Elongated_circle_2020.svg/30px-Elongated_circle_2020.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fd/Elongated_circle_2020.svg/45px-Elongated_circle_2020.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fd/Elongated_circle_2020.svg/60px-Elongated_circle_2020.svg.png 2x" width="30"/></a></span> <span class="bandeau-portail-texte"><a href="/wiki/Portail:Ann%C3%A9es_2020" title="Portail:Années 2020">Portail des années 2020</a></span> </span></li> </ul>
# <!--
# NewPP limit report
# Parsed by mw1360
# Cached time: 20210324224234
# Cache expiry: 2592000
# Dynamic content: false
# Complications: []
# CPU time usage: 3.289 seconds
# Real time usage: 4.623 seconds
# Preprocessor visited node count: 173303/1000000
# Post‐expand include size: 732461/2097152 bytes
# Template argument size: 207536/2097152 bytes
# Highest expansion depth: 18/40
# Expensive parser function count: 10/500
# Unstrip recursion depth: 0/20
# Unstrip post‐expand size: 37673/5000000 bytes
# Lua time usage: 0.289/10.000 seconds
# Lua memory usage: 5727936/52428800 bytes
# Number of Wikibase entities loaded: 1/400
# -->
# <!--
# Transclusion expansion time report (%,ms,calls,template)
# 100.00% 3803.395      1 -total
#  24.54%  933.363     20 Modèle:Foot_résultat
#  21.68%  824.732    416 Modèle:Foot_couleur
#   8.37%  318.317      1 Modèle:Infobox_Compétition_sportive
#   7.00%  266.284     60 Modèle:Foot_classement
#   5.27%  200.581      1 Modèle:Palette
#   4.71%  179.307      1 Modèle:Références
#   4.24%  161.097     38 Modèle:Trim
#   3.85%  146.427     67 Modèle:Infobox_V3/Tableau_Ligne_mixte
#   3.54%  134.547     22 Modèle:Lien_web
# -->
# <!-- Saved in parser cache with key frwiki:pcache:idhash:12518858-0!canonical and timestamp 20210324224229 and revision id 181084403. Serialized with JSON.
#  -->
# </div><noscript><img alt="" height="1" src="//fr.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1" style="border: none; position: absolute;" title="" width="1"/></noscript>
# <div class="printfooter">Ce document provient de « <a dir="ltr" href="https://fr.wikipedia.org/w/index.php?title=Championnat_de_France_de_football_2019-2020&amp;oldid=181084403">https://fr.wikipedia.org/w/index.php?title=Championnat_de_France_de_football_2019-2020&amp;oldid=181084403</a> ».</div></div>
# <div class="catlinks" data-mw="interface" id="catlinks"><div class="mw-normal-catlinks" id="mw-normal-catlinks"><a href="/wiki/Cat%C3%A9gorie:Accueil" title="Catégorie:Accueil">Catégories</a> : <ul><li><a href="/wiki/Cat%C3%A9gorie:Championnat_de_France_de_football_2019-2020" title="Catégorie:Championnat de France de football 2019-2020">Championnat de France de football 2019-2020</a></li><li><a href="/wiki/Cat%C3%A9gorie:Championnat_national_de_football_2019-2020" title="Catégorie:Championnat national de football 2019-2020">Championnat national de football 2019-2020</a></li></ul></div><div class="mw-hidden-catlinks mw-hidden-cats-hidden" id="mw-hidden-catlinks">Catégories cachées : <ul><li><a href="/wiki/Cat%C3%A9gorie:Page_utilisant_une_frise_chronologique" title="Catégorie:Page utilisant une frise chronologique">Page utilisant une frise chronologique</a></li><li><a href="/wiki/Cat%C3%A9gorie:Article_utilisant_une_Infobox" title="Catégorie:Article utilisant une Infobox">Article utilisant une Infobox</a></li><li><a href="/wiki/Cat%C3%A9gorie:Portail:Football/Articles_li%C3%A9s" title="Catégorie:Portail:Football/Articles liés">Portail:Football/Articles liés</a></li><li><a href="/wiki/Cat%C3%A9gorie:Portail:Sport/Articles_li%C3%A9s" title="Catégorie:Portail:Sport/Articles liés">Portail:Sport/Articles liés</a></li><li><a href="/wiki/Cat%C3%A9gorie:Portail:France/Articles_li%C3%A9s" title="Catégorie:Portail:France/Articles liés">Portail:France/Articles liés</a></li><li><a href="/wiki/Cat%C3%A9gorie:Portail:Europe/Articles_li%C3%A9s" title="Catégorie:Portail:Europe/Articles liés">Portail:Europe/Articles liés</a></li><li><a href="/wiki/Cat%C3%A9gorie:Portail:Monaco/Articles_li%C3%A9s" title="Catégorie:Portail:Monaco/Articles liés">Portail:Monaco/Articles liés</a></li><li><a href="/wiki/Cat%C3%A9gorie:Portail:Ann%C3%A9es_2010/Articles_li%C3%A9s" title="Catégorie:Portail:Années 2010/Articles liés">Portail:Années 2010/Articles liés</a></li><li><a href="/wiki/Cat%C3%A9gorie:Portail:XXIe_si%C3%A8cle/Articles_li%C3%A9s" title="Catégorie:Portail:XXIe siècle/Articles liés">Portail:XXIe siècle/Articles liés</a></li><li><a href="/wiki/Cat%C3%A9gorie:Portail:%C3%89poque_contemporaine/Articles_li%C3%A9s" title="Catégorie:Portail:Époque contemporaine/Articles liés">Portail:Époque contemporaine/Articles liés</a></li><li><a href="/wiki/Cat%C3%A9gorie:Portail:Ann%C3%A9es_2020/Articles_li%C3%A9s" title="Catégorie:Portail:Années 2020/Articles liés">Portail:Années 2020/Articles liés</a></li></ul></div></div>
# </div>
# </main>
# <div id="mw-data-after-content">
# <div class="read-more-container"></div>
# </div>
# </div>
# </div>
# <div class="mw-workspace-container mw-footer-container">
# <div class="mw-content-container">
# <footer class="mw-footer" id="footer" role="contentinfo">
# <ul id="footer-info">
# <li id="footer-info-lastmod"> La dernière modification de cette page a été faite le 21 mars 2021 à 12:36.</li>
# <li id="footer-info-copyright"><span style="white-space: normal"><a class="internal" href="/wiki/Wikip%C3%A9dia:Citation_et_r%C3%A9utilisation_du_contenu_de_Wikip%C3%A9dia" title="Droit d'auteur">Droit d'auteur</a> : les textes sont disponibles sous <a href="https://creativecommons.org/licenses/by-sa/3.0/deed.fr" rel="license" title="Licence Creative Commons Attribution - partage dans les mêmes conditions 3.0 non transposé">licence Creative Commons attribution, partage dans les mêmes conditions</a> ; d’autres conditions peuvent s’appliquer. Voyez les <a href="https://wikimediafoundation.org/wiki/Conditions_d%27utilisation" title="Conditions d’utilisation de la Wikimedia Foundation">conditions d’utilisation</a> pour plus de détails, ainsi que les <a class="internal" href="/wiki/Wikip%C3%A9dia:Cr%C3%A9dits_graphiques" title="Droit d'auteur de certaines icônes">crédits graphiques</a>. En cas de réutilisation des textes de cette page, voyez <a class="internal" href="/wiki/Sp%C3%A9cial:Citer/Championnat_de_France_de_football_2019-2020" title="Citer ou réutiliser cette page">comment citer les auteurs et mentionner la licence</a>.<br/>
# Wikipedia® est une marque déposée de la <a href="https://wikimediafoundation.org/" title="Wikimedia Foundation">Wikimedia Foundation, Inc.</a>, organisation de bienfaisance régie par le paragraphe <a class="internal" href="/wiki/501c" title="501c">501(c)(3)</a> du code fiscal des États-Unis.</span><br/></li>
# </ul>
# <ul id="footer-places">
# <li id="footer-places-privacy"><a class="extiw" href="https://meta.wikimedia.org/wiki/Privacy_policy/fr" title="m:Privacy policy/fr">Politique de confidentialité</a></li>
# <li id="footer-places-about"><a href="/wiki/Wikip%C3%A9dia:%C3%80_propos_de_Wikip%C3%A9dia" title="Wikipédia:À propos de Wikipédia">À propos de Wikipédia</a></li>
# <li id="footer-places-disclaimer"><a href="/wiki/Wikip%C3%A9dia:Avertissements_g%C3%A9n%C3%A9raux" title="Wikipédia:Avertissements généraux">Avertissements</a></li>
# <li id="footer-places-contact"><a href="//fr.wikipedia.org/wiki/Wikipédia:Contact">Contact</a></li>
# <li id="footer-places-mobileview"><a class="noprint stopMobileRedirectToggle" href="//fr.m.wikipedia.org/w/index.php?title=Championnat_de_France_de_football_2019-2020&amp;mobileaction=toggle_view_mobile">Version mobile</a></li>
# <li id="footer-places-developers"><a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">Développeurs</a></li>
# <li id="footer-places-statslink"><a href="https://stats.wikimedia.org/#/fr.wikipedia.org">Statistiques</a></li>
# <li id="footer-places-cookiestatement"><a href="https://foundation.wikimedia.org/wiki/Cookie_statement">Déclaration sur les témoins (cookies)</a></li>
# </ul>
# <ul class="noprint" id="footer-icons">
# <li id="footer-copyrightico"><a href="https://wikimediafoundation.org/"><img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88"/></a></li>
# <li id="footer-poweredbyico"><a href="https://www.mediawiki.org/"><img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/footer/poweredby_mediawiki_88x31.png" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88"/></a></li>
# </ul>
# <div style="clear: both;"></div>
# </footer>
# </div>
# </div>
# </div>
# </div>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"3.289","walltime":"4.623","ppvisitednodes":{"value":173303,"limit":1000000},"postexpandincludesize":{"value":732461,"limit":2097152},"templateargumentsize":{"value":207536,"limit":2097152},"expansiondepth":{"value":18,"limit":40},"expensivefunctioncount":{"value":10,"limit":500},"unstrip-depth":{"value":0,"limit":20},"unstrip-size":{"value":37673,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00% 3803.395      1 -total"," 24.54%  933.363     20 Modèle:Foot_résultat"," 21.68%  824.732    416 Modèle:Foot_couleur","  8.37%  318.317      1 Modèle:Infobox_Compétition_sportive","  7.00%  266.284     60 Modèle:Foot_classement","  5.27%  200.581      1 Modèle:Palette","  4.71%  179.307      1 Modèle:Références","  4.24%  161.097     38 Modèle:Trim","  3.85%  146.427     67 Modèle:Infobox_V3/Tableau_Ligne_mixte","  3.54%  134.547     22 Modèle:Lien_web"]},"scribunto":{"limitreport-timeusage":{"value":"0.289","limit":"10.000"},"limitreport-memusage":{"value":5727936,"limit":52428800}},"cachereport":{"origin":"mw1360","timestamp":"20210324224234","ttl":2592000,"transientcontent":false}}});});</script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Article","name":"Championnat de France de football 2019-2020","url":"https:\/\/fr.wikipedia.org\/wiki\/Championnat_de_France_de_football_2019-2020","sameAs":"http:\/\/www.wikidata.org\/entity\/Q61862323","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q61862323","author":{"@type":"Organization","name":"Contributeurs aux projets Wikimedia"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2019-04-28T11:04:48Z","dateModified":"2021-03-21T11:36:35Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/fr\/1\/14\/Ligue_1_Conforama.svg","headline":"82e \u00e9dition du championnat de France de football"}</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":211,"wgHostname":"mw1331"});});</script>
# </body></html>

# %% [markdown]
# Si on print l'objet, page créée avec BeautifulSoup, on voit que ce n'est plus une chaine de caractères mais bien une page HTML avec des balises. On peut à présenter chercher des élements à l'intérieur de ces balises.
#
#
# par exemple, si on veut connaire le titre de la page, on utilise la méthode .find et on lui demande "title"

# %%
print(page.find("title"))
# Out:
# <title>Championnat de France de football 2019-2020 — Wikipédia</title>

# %% [markdown]
# La methode ``.find`` ne renvoie que la première occurence de l'élément

# %%
print(page.find("table"))
# Out:
# <table><caption style="background:#99cc99;color:#000000;">Généralités</caption><tbody><tr>
# <th scope="row" style="width:10.5em;">Sport</th>
# <td>
# <a href="/wiki/Football" title="Football">Football</a></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Organisateur(s)</th>
# <td>
# <a href="/wiki/Ligue_de_football_professionnel" title="Ligue de football professionnel">LFP</a></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Édition</th>
# <td>
# <abbr class="abbr" title="Quatre-vingt-deuxième (huitante-deuxième / octante-deuxième)">82<sup>e</sup></abbr></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Lieu(x)</th>
# <td>
# <span class="datasortkey" data-sort-value="France"><span class="flagicon"><a class="image" href="/wiki/Fichier:Flag_of_France.svg" title="Drapeau de la France"><img alt="Drapeau de la France" class="noviewer thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Flag_of_France.svg/20px-Flag_of_France.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Flag_of_France.svg/30px-Flag_of_France.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Flag_of_France.svg/40px-Flag_of_France.svg.png 2x" width="20"/></a> </span><a href="/wiki/France" title="France">France</a></span> et <br/><span class="datasortkey" data-sort-value="Monaco"><span class="flagicon"><a class="image" href="/wiki/Fichier:Flag_of_Monaco.svg" title="Drapeau de Monaco"><img alt="Drapeau de Monaco" class="noviewer thumbborder" data-file-height="800" data-file-width="1000" decoding="async" height="16" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Flag_of_Monaco.svg/20px-Flag_of_Monaco.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Flag_of_Monaco.svg/30px-Flag_of_Monaco.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Flag_of_Monaco.svg/40px-Flag_of_Monaco.svg.png 2x" width="20"/></a> </span><a href="/wiki/Monaco" title="Monaco">Monaco</a></span></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Date</th>
# <td>
# Du <time class="nowrap date-lien" data-sort-value="2019-08-09" datetime="2019-08-09"><a href="/wiki/9_ao%C3%BBt_en_sport" title="9 août en sport">9</a> <a class="mw-redirect" href="/wiki/Ao%C3%BBt_2019_en_sport" title="Août 2019 en sport">août</a> <a href="/wiki/2019_en_football" title="2019 en football">2019</a></time><br/>au <time class="nowrap date-lien" data-sort-value="2020-03-08" datetime="2020-03-08"><a href="/wiki/8_mars_en_sport" title="8 mars en sport">8 mars</a> <a href="/wiki/2020_en_football" title="2020 en football">2020</a></time> <small>(arrêt définitif)</small></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Participants</th>
# <td>
# 20 équipes</td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Matchs joués</th>
# <td>
# 279</td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Site web officiel</th>
# <td>
# <a class="external text" href="https://www.ligue1.fr/" rel="nofollow">Site officiel</a></td>
# </tr></tbody></table>

# %% [markdown]
# ---------------
# Pour trouver toutes les occurences, on utilise ``.findAll()``.

# %%
print("Il y a", len(page.findAll("table")), "éléments dans la page qui sont des <table>")
# Out:
# Il y a 34 éléments dans la page qui sont des <table>

# %%
print(" Le 2eme tableau de la page : Hiérarchie \n", page.findAll("table")[1])
print("--------------------------------------------------------")
print("Le 3eme tableau de la page : Palmarès \n",page.findAll("table")[2])
# Out:
#  Le 2eme tableau de la page : Hiérarchie
#  <table><caption style="background:#99cc99;color:#000000;">Hiérarchie</caption><tbody><tr>
# <th scope="row" style="width:10.5em;">Hiérarchie</th>
# <td>
# <abbr class="abbr" title="Premier">1<sup>er</sup></abbr> échelon</td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Niveau inférieur</th>
# <td>
# <a class="mw-redirect" href="/wiki/Championnat_de_France_de_football_de_Ligue_2_2019-2020" title="Championnat de France de football de Ligue 2 2019-2020">Ligue 2 2019-2020</a></td>
# </tr></tbody></table>
# --------------------------------------------------------
# Le 3eme tableau de la page : Palmarès
#  <table><caption style="background:#99cc99;color:#000000;">Palmarès</caption>
# <tbody><tr>
# <th scope="row" style="width:10.5em;">Tenant du titre</th>
# <td>
# <a href="/wiki/Paris_Saint-Germain_Football_Club" title="Paris Saint-Germain Football Club">Paris Saint-Germain</a> (8)</td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Promu(s) en début de saison</th>
# <td>
# <a href="/wiki/Football_Club_de_Metz" title="Football Club de Metz">FC Metz</a><br/><a href="/wiki/Stade_brestois_29" title="Stade brestois 29">Stade brestois 29</a></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Vainqueur</th>
# <td>
# <b><a href="/wiki/Paris_Saint-Germain_Football_Club" title="Paris Saint-Germain Football Club">Paris Saint-Germain</a> (9)</b></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Deuxième</th>
# <td>
# <a href="/wiki/Olympique_de_Marseille" title="Olympique de Marseille">Olympique de Marseille</a></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Troisième</th>
# <td>
# <a class="mw-redirect" href="/wiki/Stade_rennais_football_club" title="Stade rennais football club">Stade rennais FC</a></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Relégué(s)</th>
# <td>
# <a href="/wiki/Amiens_Sporting_Club" title="Amiens Sporting Club">Amiens SC</a><br/><a href="/wiki/Toulouse_Football_Club" title="Toulouse Football Club">Toulouse FC</a></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Buts</th>
# <td>
# 702 <small>(2,51 buts par match)</small></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;"><img alt="Averti" data-file-height="260" data-file-width="200" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Yellow_card.svg/10px-Yellow_card.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Yellow_card.svg/15px-Yellow_card.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Yellow_card.svg/20px-Yellow_card.svg.png 2x" title="Averti" width="10"/> Cartons jaunes</th>
# <td>
# 1029 <small>(3,68 par match)</small></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;"><a class="image" href="/wiki/Fichier:Red_card.svg"><img alt="Red card.svg" data-file-height="260" data-file-width="200" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/e7/Red_card.svg/10px-Red_card.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/e7/Red_card.svg/15px-Red_card.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/e/e7/Red_card.svg/20px-Red_card.svg.png 2x" width="10"/></a> Cartons rouges</th>
# <td>
# 70 <small>(0,25 par match)</small></td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Meilleur joueur</th>
# <td>
# Non attribué</td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Meilleur(s) buteur(s)</th>
# <td>
# <span class="flagicon"><a class="image" href="/wiki/Fichier:Flag_of_France.svg" title="Drapeau : France"><img alt="Drapeau : France" class="noviewer thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Flag_of_France.svg/20px-Flag_of_France.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Flag_of_France.svg/30px-Flag_of_France.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Flag_of_France.svg/40px-Flag_of_France.svg.png 2x" width="20"/></a></span> <a href="/wiki/Kylian_Mbapp%C3%A9" title="Kylian Mbappé">Kylian Mbappé</a> (18)</td>
# </tr>
# <tr>
# <th scope="row" style="width:10.5em;">Meilleur(s) passeur(s)</th>
# <td>
# <span class="flagicon"><a class="image" href="/wiki/Fichier:Flag_of_Argentina.svg" title="Drapeau : Argentine"><img alt="Drapeau : Argentine" class="noviewer thumbborder" data-file-height="500" data-file-width="800" decoding="async" height="13" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/20px-Flag_of_Argentina.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/30px-Flag_of_Argentina.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Flag_of_Argentina.svg/40px-Flag_of_Argentina.svg.png 2x" width="20"/></a></span> <a href="/wiki/%C3%81ngel_Di_Mar%C3%ADa" title="Ángel Di María">Ángel Di María</a> (14)</td>
# </tr>
# </tbody></table>

# %% [markdown]
# ### Exercice guidé : obtenir la liste des équipes de Ligue 1
#
# La liste des équipes est dans le tableau ``"Participants"`` : dans le code source, on voit que ce tableau est celui qui a ``class="DebutCarte"``. On voit également que les balises qui encerclent les noms et les urls des clubs sont de la forme suivante

# %% [markdown]
# ```
# <a href="url_club" title="nom_club"> Nom du club </a>
# ```

# %%
for item in page.find('table', {'class' : 'DebutCarte'}).findAll({'a'})[0:5] : 
    print(item, "\n-------")
# Out:
# <a class="image" href="/wiki/Fichier:France_location_map-Regions-2016.svg"><img alt="France location map-Regions-2016.svg" data-file-height="1922" data-file-width="2000" decoding="async" height="288" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/France_location_map-Regions-2016.svg/300px-France_location_map-Regions-2016.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/France_location_map-Regions-2016.svg/450px-France_location_map-Regions-2016.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b1/France_location_map-Regions-2016.svg/600px-France_location_map-Regions-2016.svg.png 2x" width="300"/></a>
# -------
# <a href="/wiki/Paris_Saint-Germain_Football_Club" title="Paris Saint-Germain Football Club">Paris SG</a>
# -------
# <a href="/wiki/LOSC_Lille" title="LOSC Lille">LOSC Lille</a>
# -------
# <a href="/wiki/Olympique_lyonnais" title="Olympique lyonnais">Olympique lyonnais</a>
# -------
# <a href="/wiki/Association_sportive_de_Saint-%C3%89tienne" title="Association sportive de Saint-Étienne">AS Saint-Étienne</a>
# -------

# %% [markdown]
# On n'a pas envie de prendre le premier élément qui ne correspond pas à un club mais à une image.
# Or cet élément est le seul qui n'ait pas de ``title=""``. Il est conseillé d'exclure les élements qui ne nous intéressent pas en indiquant les éléments que la ligne doit avoir au lieu de les exclure en fonction de leur place dans la liste.

# %%
### condition sur la place dans la liste >>>> MAUVAIS
for e, item in enumerate(page.find('table', {'class' : 'DebutCarte'}).findAll({'a'})[0:5]) : 
    if  e == 0: 
        pass
    else : 
        print(item)
# Out:
# <a href="/wiki/Paris_Saint-Germain_Football_Club" title="Paris Saint-Germain Football Club">Paris SG</a>
# <a href="/wiki/LOSC_Lille" title="LOSC Lille">LOSC Lille</a>
# <a href="/wiki/Olympique_lyonnais" title="Olympique lyonnais">Olympique lyonnais</a>
# <a href="/wiki/Association_sportive_de_Saint-%C3%89tienne" title="Association sportive de Saint-Étienne">AS Saint-Étienne</a>

# %%
#### condition sur les éléments que doit avoir la ligne >>>> BIEN 
for item in page.find('table', {'class' : 'DebutCarte'}).findAll({'a'})[0:5] : 
    if item.get("title") :
        print(item)
# Out:
# <a href="/wiki/Paris_Saint-Germain_Football_Club" title="Paris Saint-Germain Football Club">Paris SG</a>
# <a href="/wiki/LOSC_Lille" title="LOSC Lille">LOSC Lille</a>
# <a href="/wiki/Olympique_lyonnais" title="Olympique lyonnais">Olympique lyonnais</a>
# <a href="/wiki/Association_sportive_de_Saint-%C3%89tienne" title="Association sportive de Saint-Étienne">AS Saint-Étienne</a>

# %% [markdown]
# Enfin la dernière étape, consiste à obtenir les informations souhaitées, c'est à dire dans notre cas, le nom et l'url des 20 clubs. Pour cela, nous allons utiliser deux méthodes de l'élement item :
#
# - ``getText()`` qui permet d'obtenir le texte qui est sur la page web et dans la balise  ``<a>``
# - ``get('xxxx')`` qui permet d'obtenir l'élément qui est égal à ``xxxx``
#
# Dans notre cas, nous allons vouloir le nom du club ainsi que l'url : on va donc utiliser ``__getText__`` et ``__get("href")__``.

# %%
for item in page.find('table', {'class' : 'DebutCarte'}).findAll({'a'})[0:5] : 
    if item.get("title") :
        print(item.get("href"))
        print(item.getText())
# Out:
# /wiki/Paris_Saint-Germain_Football_Club
# Paris SG
# /wiki/LOSC_Lille
# LOSC Lille
# /wiki/Olympique_lyonnais
# Olympique lyonnais
# /wiki/Association_sportive_de_Saint-%C3%89tienne
# AS Saint-Étienne

# %%
# pour avoir le nom officiel, on aurait utiliser l'élément <title>
for item in page.find('table', {'class' : 'DebutCarte'}).findAll({'a'})[0:5] : 
    if item.get("title") :
        print(item.get("title"))
# Out:
# Paris Saint-Germain Football Club
# LOSC Lille
# Olympique lyonnais
# Association sportive de Saint-Étienne

# %% [markdown]
# Toutes ces informations, on souhaite les conserver dans un tableau *Excel* pour pouvoir les réuitiliser à l'envie : pour cela, rien de plus simple, on va passer par pandas, parce qu'on le maitrise parfaitement à ce stade de la formation.

# %%
import pandas

liste_noms = []
liste_urls = []

for item in page.find('table', {'class' : 'DebutCarte'}).findAll({'a'}) : 
    if item.get("title") :
        liste_urls.append(item.get("href"))
        liste_noms.append(item.getText())
        
df = pandas.DataFrame.from_dict( {"clubs" : liste_noms, 'url' : liste_urls})
df.head()
# Out:
#                    clubs                                               url
# 0               Paris SG           /wiki/Paris_Saint-Germain_Football_Club
# 1             LOSC Lille                                  /wiki/LOSC_Lille
# 2     Olympique lyonnais                          /wiki/Olympique_lyonnais
# 3       AS Saint-Étienne  /wiki/Association_sportive_de_Saint-%C3%89tienne
# 4  Olympique deMarseille                      /wiki/Olympique_de_Marseille

# %% [markdown]
# ### Exercice de web scraping avec BeautifulSoup
#
# Pour cet exercice, nous vous demandons d'obtenir 1) les informations personnelles des 721 pokemons sur le site internet [pokemondb.net](http://pokemondb.net/pokedex/national). Les informations que nous aimerions obtenir au final pour les pokemons sont celles contenues dans 4 tableaux :
#
# - Pokédex data
# - Training
# - Breeding
# - Base stats
#
# Pour exemple : [Pokemon Database](http://pokemondb.net/pokedex/nincada).
#
# 2) Nous aimerions que vous récupériez également les images de chacun des pokémons et que vous les enregistriez dans un dossier  (indice : utilisez les modules request et [shutil](https://docs.python.org/3/library/shutil.html))
# _pour cette question ci, il faut que vous cherchiez de vous même certains éléments, tout n'est pas présent dans le TD_.

# %% [markdown]
# #### Récupération des infos sur un pokemon

# %%
# Récupération des infos sur un pokemon https://pokemondb.net/pokedex/bulbasaur
import urllib
import bs4
from urllib.request import Request, urlopen

# Etape 1 : se connecter à la page et obtenir le code source
# utilisation de l'objet requête avec en-tête pour éviter une erreur "HTTP Error 403: Forbidden"

url_pokemon = "https://pokemondb.net/pokedex/bulbasaur"

req = Request(url_pokemon, headers={'User-Agent': 'Mozilla/5.0'})
html = urlopen(req).read().decode('utf-8')
print(html[:1000])
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8">
# <title>Bulbasaur Pokédex: stats, moves, evolution &amp; locations | Pokémon Database</title>
# <link rel="preconnect" href="https://img.pokemondb.net">
# <style>@font-face{font-family:'Fira Sans';font-style:normal;font-weight:400;font-display:swap;src:url("/static/fonts/fira-sans-v10-latin-400.woff2") format("woff2");unicode-range:U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD}@font-face{font-family:'Fira Sans';font-style:italic;font-weight:400;font-display:swap;src:url("/static/fonts/fira-sans-v10-latin-400i.woff2") format("woff2");unicode-range:U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD}@font-face{font-family:'Fira Sans';font-style:normal;font-weight:700;font-display:swap;src:url("/static/fonts/fira-sans-v10-l

# %%
# Etape 2 : utiliser le package BeautifulSoup
# qui "comprend" les balises contenues dans la chaine de caractères renvoyée par la fonction request
# utilisation du parser de la doc de bs 'html.parser'

page = bs4.BeautifulSoup(html, 'html.parser')

# %%
# Etape 3: les données recherchées sont dans des tables du type <table class="vitals-table">
len(page.findAll('table', {'class' : 'vitals-table'}))
# Out:
# 7

# %% [markdown]
# Donées recherchées:
# - Pokédex data
# - Training
# - Breeding
# - Base stats

# %%
# les données recherchées sont stockées dans un dictionnaire de caractéristiques
# `feature` = {nom de la caractéristique: valeur}
feature = {}

# %%
# Affichage du code html de la première table qui contient les "Pokédex data"
table = page.findAll('table', {'class' : 'vitals-table'})[0]
print(table.prettify())

# Dans une ligne du tableau <tr> ... </tr>
# on récupère l'information de l'en-tête qui servira de clé <th> ... </th>
# la valeur sera le contenu de du <td> ... </td> correpondant
# Out:
# <table class="vitals-table">
#  <tbody>
#   <tr>
#    <th>
#     National №
#    </th>
#    <td>
#     <strong>
#      001
#     </strong>
#    </td>
#   </tr>
#   <tr>
#    <th>
#     Type
#    </th>
#    <td>
#     <a class="type-icon type-grass" href="/type/grass">
#      Grass
#     </a>
#     <a class="type-icon type-poison" href="/type/poison">
#      Poison
#     </a>
#    </td>
#   </tr>
#   <tr>
#    <th>
#     Species
#    </th>
#    <td>
#     Seed Pokémon
#    </td>
#   </tr>
#   <tr>
#    <th>
#     Height
#    </th>
#    <td>
#     0.7 m (2′04″)
#    </td>
#   </tr>
#   <tr>
#    <th>
#     Weight
#    </th>
#    <td>
#     6.9 kg (15.2 lbs)
#    </td>
#   </tr>
#   <tr>
#    <th>
#     Abilities
#    </th>
#    <td>
#     <span class="text-muted">
#      1.
#      <a href="/ability/overgrow" title="Powers up Grass-type moves in a pinch.">
#       Overgrow
#      </a>
#     </span>
#     <br/>
#     <small class="text-muted">
#      <a href="/ability/chlorophyll" title="Boosts the Pokémon's Speed in sunshine.">
#       Chlorophyll
#      </a>
#      (hidden ability)
#     </small>
#     <br/>
#    </td>
#   </tr>
#   <tr>
#    <th>
#     Local №
#    </th>
#    <td>
#     001
#     <small class="text-muted">
#      (Red/Blue/Yellow)
#     </small>
#     <br/>
#     226
#     <small class="text-muted">
#      (Gold/Silver/Crystal)
#     </small>
#     <br/>
#     001
#     <small class="text-muted">
#      (FireRed/LeafGreen)
#     </small>
#     <br/>
#     231
#     <small class="text-muted">
#      (HeartGold/SoulSilver)
#     </small>
#     <br/>
#     080
#     <small class="text-muted">
#      (X/Y — Central Kalos)
#     </small>
#     <br/>
#     001
#     <small class="text-muted">
#      (Let's Go Pikachu/Let's Go Eevee)
#     </small>
#     <br/>
#     068
#     <small class="text-muted">
#      (The Isle of Armor)
#     </small>
#     <br/>
#    </td>
#   </tr>
#  </tbody>
# </table>

# %%
# Dans une ligne du tableau <tr> ... </tr>
# on récupère l'information de l'en-tête qui servira de clé <th> ... </th>
# la valeur sera le contenu de du <td> ... </td> correpondant
for row in table.findAll({'tr'}) :
    print(row.th.string)
    print(row.td.getText())
    print("---")
# Out:
# National №
# 001
# ---
# Type
#
# Grass Poison
# ---
# Species
# Seed Pokémon
# ---
# Height
# 0.7 m (2′04″)
# ---
# Weight
# 6.9 kg (15.2 lbs)
# ---
# Abilities
# 1. OvergrowChlorophyll (hidden ability)
# ---
# Local №
# 001 (Red/Blue/Yellow)226 (Gold/Silver/Crystal)001 (FireRed/LeafGreen)231 (HeartGold/SoulSilver)080 (X/Y — Central Kalos)001 (Let's Go Pikachu/Let's Go Eevee)068 (The Isle of Armor)
# ---

# %%
feature.clear()

# %%
# Alimentation du dictionnaire de caractéristiques
for row in table.findAll({'tr'}) :
    key = row.th.string
    value = row.td.getText()
    feature[key] = value

feature
# Out:
# {'National №': '001',
#  'Type': '\nGrass Poison ',
#  'Species': 'Seed Pokémon',
#  'Height': '0.7\xa0m (2′04″)',
#  'Weight': '6.9\xa0kg (15.2\xa0lbs)',
#  'Abilities': '1. OvergrowChlorophyll (hidden ability)',
#  'Local №': "001 (Red/Blue/Yellow)226 (Gold/Silver/Crystal)001 (FireRed/LeafGreen)231 (HeartGold/SoulSilver)080 (X/Y — Central Kalos)001 (Let's Go Pikachu/Let's Go Eevee)068 (The Isle of Armor)"}

# %%
# Récupération des 4 tables souhaitées:
feature.clear()
tables = page.findAll('table', {'class' : 'vitals-table'})
for table in tables[:4]:
    for row in table.findAll({'tr'}) :
        key = row.th.string
        value = row.td.getText()
        feature[key] = value
feature
# Out:
# {'National №': '001',
#  'Type': '\nGrass Poison ',
#  'Species': 'Seed Pokémon',
#  'Height': '0.7\xa0m (2′04″)',
#  'Weight': '6.9\xa0kg (15.2\xa0lbs)',
#  'Abilities': '1. OvergrowChlorophyll (hidden ability)',
#  'Local №': "001 (Red/Blue/Yellow)226 (Gold/Silver/Crystal)001 (FireRed/LeafGreen)231 (HeartGold/SoulSilver)080 (X/Y — Central Kalos)001 (Let's Go Pikachu/Let's Go Eevee)068 (The Isle of Armor)",
#  'EV yield': '\n1 Special Attack ',
#  'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#  None: '\n50 (normal)\n',
#  'Base Exp.': '64',
#  'Growth Rate': 'Medium Slow',
#  'Egg Groups': 'Grass, Monster',
#  'Gender': '87.5% male, 12.5% female',
#  'Egg cycles': '20 (4,884–5,140 steps)\n',
#  'HP': '45',
#  'Attack': '49',
#  'Defense': '49',
#  'Sp. Atk': '65',
#  'Sp. Def': '65',
#  'Speed': '45',
#  'Total': '318'}

# %%
# Fonction de récupération des caractéristiques pour un pokémon
def get_features(url_pokemon):
    feature = {}

    req = Request(url_pokemon, headers={'User-Agent': 'Mozilla/5.0'})
    html = urlopen(req).read().decode('utf-8')
    page = bs4.BeautifulSoup(html, 'html.parser')

    tables = page.findAll('table', {'class' : 'vitals-table'})
    for table in tables[:4]:
        for row in table.findAll({'tr'}) :
            key = row.th.string
            value = row.td.getText()
            feature[key] = value
    return feature

# %%
get_features("https://pokemondb.net/pokedex/bulbasaur")
# Out:
# {'National №': '001',
#  'Type': '\nGrass Poison ',
#  'Species': 'Seed Pokémon',
#  'Height': '0.7\xa0m (2′04″)',
#  'Weight': '6.9\xa0kg (15.2\xa0lbs)',
#  'Abilities': '1. OvergrowChlorophyll (hidden ability)',
#  'Local №': "001 (Red/Blue/Yellow)226 (Gold/Silver/Crystal)001 (FireRed/LeafGreen)231 (HeartGold/SoulSilver)080 (X/Y — Central Kalos)001 (Let's Go Pikachu/Let's Go Eevee)068 (The Isle of Armor)",
#  'EV yield': '\n1 Special Attack ',
#  'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#  None: '\n50 (normal)\n',
#  'Base Exp.': '64',
#  'Growth Rate': 'Medium Slow',
#  'Egg Groups': 'Grass, Monster',
#  'Gender': '87.5% male, 12.5% female',
#  'Egg cycles': '20 (4,884–5,140 steps)\n',
#  'HP': '45',
#  'Attack': '49',
#  'Defense': '49',
#  'Sp. Atk': '65',
#  'Sp. Def': '65',
#  'Speed': '45',
#  'Total': '318'}

# %% [markdown]
# #### Récupération de la liste des pokemons

# %%
# Récupération de la liste des pokemons et des liens vers leur page de caractéristiques
# https://pokemondb.net/pokedex/all

# %%
url_pokemons_list = "https://pokemondb.net/pokedex/all"

req = Request(url_pokemons_list, headers={'User-Agent': 'Mozilla/5.0'})
html = urlopen(req).read().decode('utf-8')
print(html[:1000])
page = bs4.BeautifulSoup(html, 'html.parser')
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8">
# <title>Pokémon Pokédex: list of Pokémon with stats | Pokémon Database</title>
# <link rel="preconnect" href="https://img.pokemondb.net">
# <style>@font-face{font-family:'Fira Sans';font-style:normal;font-weight:400;font-display:swap;src:url("/static/fonts/fira-sans-v10-latin-400.woff2") format("woff2");unicode-range:U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD}@font-face{font-family:'Fira Sans';font-style:italic;font-weight:400;font-display:swap;src:url("/static/fonts/fira-sans-v10-latin-400i.woff2") format("woff2");unicode-range:U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD}@font-face{font-family:'Fira Sans';font-style:normal;font-weight:700;font-display:swap;src:url("/static/fonts/fira-sans-v10-latin-600.woff2"

# %%
# <table id="pokedex" class="data-table block-wide">
table = page.find('table', id = 'pokedex')
for item in table.findAll('a', {'class':'ent-name'})[:10]:
    print(item)
# Out:
# <a class="ent-name" href="/pokedex/bulbasaur" title="View Pokedex for #001 Bulbasaur">Bulbasaur</a>
# <a class="ent-name" href="/pokedex/ivysaur" title="View Pokedex for #002 Ivysaur">Ivysaur</a>
# <a class="ent-name" href="/pokedex/venusaur" title="View Pokedex for #003 Venusaur">Venusaur</a>
# <a class="ent-name" href="/pokedex/venusaur" title="View Pokedex for #003 Venusaur">Venusaur</a>
# <a class="ent-name" href="/pokedex/charmander" title="View Pokedex for #004 Charmander">Charmander</a>
# <a class="ent-name" href="/pokedex/charmeleon" title="View Pokedex for #005 Charmeleon">Charmeleon</a>
# <a class="ent-name" href="/pokedex/charizard" title="View Pokedex for #006 Charizard">Charizard</a>
# <a class="ent-name" href="/pokedex/charizard" title="View Pokedex for #006 Charizard">Charizard</a>
# <a class="ent-name" href="/pokedex/charizard" title="View Pokedex for #006 Charizard">Charizard</a>
# <a class="ent-name" href="/pokedex/squirtle" title="View Pokedex for #007 Squirtle">Squirtle</a>

# %%
pokemons = {}  # { name : url}
table = page.find('table', id = 'pokedex')
for item in table.findAll('a', {'class':'ent-name'}):
    name = item.getText()
    url = item.get("href")
    pokemons[name] = url
len(pokemons)
# Out:
# 898

# %%
#### Récupération des informations pour tous les pokemons
infos = {}  # { pokemon name : features }
for name, end_of_url in pokemons.items():
    url_pokemon = "https://pokemondb.net" + end_of_url
    infos[name] = get_features(url_pokemon)

# %%
infos
# Out:
# {'Bulbasaur': {'National №': '001',
#   'Type': '\nGrass Poison ',
#   'Species': 'Seed Pokémon',
#   'Height': '0.7\xa0m (2′04″)',
#   'Weight': '6.9\xa0kg (15.2\xa0lbs)',
#   'Abilities': '1. OvergrowChlorophyll (hidden ability)',
#   'Local №': "001 (Red/Blue/Yellow)226 (Gold/Silver/Crystal)001 (FireRed/LeafGreen)231 (HeartGold/SoulSilver)080 (X/Y — Central Kalos)001 (Let's Go Pikachu/Let's Go Eevee)068 (The Isle of Armor)",
#   'EV yield': '\n1 Special Attack ',
#   'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '64',
#   'Growth Rate': 'Medium Slow',
#   'Egg Groups': 'Grass, Monster',
#   'Gender': '87.5% male, 12.5% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '45',
#   'Attack': '49',
#   'Defense': '49',
#   'Sp. Atk': '65',
#   'Sp. Def': '65',
#   'Speed': '45',
#   'Total': '318'},
#  'Ivysaur': {'National №': '002',
#   'Type': '\nGrass Poison ',
#   'Species': 'Seed Pokémon',
#   'Height': '1.0\xa0m (3′03″)',
#   'Weight': '13.0\xa0kg (28.7\xa0lbs)',
#   'Abilities': '1. OvergrowChlorophyll (hidden ability)',
#   'Local №': "002 (Red/Blue/Yellow)227 (Gold/Silver/Crystal)002 (FireRed/LeafGreen)232 (HeartGold/SoulSilver)081 (X/Y — Central Kalos)002 (Let's Go Pikachu/Let's Go Eevee)069 (The Isle of Armor)",
#   'EV yield': '\n1 Special Attack, 1 Special Defense ',
#   'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '142',
#   'Growth Rate': 'Medium Slow',
#   'Egg Groups': 'Grass, Monster',
#   'Gender': '87.5% male, 12.5% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '60',
#   'Attack': '62',
#   'Defense': '63',
#   'Sp. Atk': '80',
#   'Sp. Def': '80',
#   'Speed': '60',
#   'Total': '405'},
#  'Venusaur': {'National №': '003',
#   'Type': '\nGrass Poison ',
#   'Species': 'Seed Pokémon',
#   'Height': '2.0\xa0m (6′07″)',
#   'Weight': '100.0\xa0kg (220.5\xa0lbs)',
#   'Abilities': '1. OvergrowChlorophyll (hidden ability)',
#   'Local №': "003 (Red/Blue/Yellow)228 (Gold/Silver/Crystal)003 (FireRed/LeafGreen)233 (HeartGold/SoulSilver)082 (X/Y — Central Kalos)003 (Let's Go Pikachu/Let's Go Eevee)070 (The Isle of Armor)",
#   'EV yield': '\n2 Special Attack, 1 Special Defense ',
#   'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '236',
#   'Growth Rate': 'Medium Slow',
#   'Egg Groups': 'Grass, Monster',
#   'Gender': '87.5% male, 12.5% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '80',
#   'Attack': '82',
#   'Defense': '83',
#   'Sp. Atk': '100',
#   'Sp. Def': '100',
#   'Speed': '80',
#   'Total': '525'},
#  'Charmander': {'National №': '004',
#   'Type': '\nFire ',
#   'Species': 'Lizard Pokémon',
#   'Height': '0.6\xa0m (2′00″)',
#   'Weight': '8.5\xa0kg (18.7\xa0lbs)',
#   'Abilities': '1. BlazeSolar Power (hidden ability)',
#   'Local №': "004 (Red/Blue/Yellow)229 (Gold/Silver/Crystal)004 (FireRed/LeafGreen)234 (HeartGold/SoulSilver)083 (X/Y — Central Kalos)004 (Let's Go Pikachu/Let's Go Eevee)378 (Sword/Shield)",
#   'EV yield': '\n1 Speed ',
#   'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '62',
#   'Growth Rate': 'Medium Slow',
#   'Egg Groups': 'Dragon, Monster',
#   'Gender': '87.5% male, 12.5% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '39',
#   'Attack': '52',
#   'Defense': '43',
#   'Sp. Atk': '60',
#   'Sp. Def': '50',
#   'Speed': '65',
#   'Total': '309'},
#  'Charmeleon': {'National №': '005',
#   'Type': '\nFire ',
#   'Species': 'Flame Pokémon',
#   'Height': '1.1\xa0m (3′07″)',
#   'Weight': '19.0\xa0kg (41.9\xa0lbs)',
#   'Abilities': '1. BlazeSolar Power (hidden ability)',
#   'Local №': "005 (Red/Blue/Yellow)230 (Gold/Silver/Crystal)005 (FireRed/LeafGreen)235 (HeartGold/SoulSilver)084 (X/Y — Central Kalos)005 (Let's Go Pikachu/Let's Go Eevee)379 (Sword/Shield)",
#   'EV yield': '\n1 Special Attack, 1 Speed ',
#   'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '142',
#   'Growth Rate': 'Medium Slow',
#   'Egg Groups': 'Dragon, Monster',
#   'Gender': '87.5% male, 12.5% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '58',
#   'Attack': '64',
#   'Defense': '58',
#   'Sp. Atk': '80',
#   'Sp. Def': '65',
#   'Speed': '80',
#   'Total': '405'},
#  'Charizard': {'National №': '006',
#   'Type': '\nFire Flying ',
#   'Species': 'Flame Pokémon',
#   'Height': '1.7\xa0m (5′07″)',
#   'Weight': '90.5\xa0kg (199.5\xa0lbs)',
#   'Abilities': '1. BlazeSolar Power (hidden ability)',
#   'Local №': "006 (Red/Blue/Yellow)231 (Gold/Silver/Crystal)006 (FireRed/LeafGreen)236 (HeartGold/SoulSilver)085 (X/Y — Central Kalos)006 (Let's Go Pikachu/Let's Go Eevee)380 (Sword/Shield)",
#   'EV yield': '\n3 Special Attack ',
#   'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '240',
#   'Growth Rate': 'Medium Slow',
#   'Egg Groups': 'Dragon, Monster',
#   'Gender': '87.5% male, 12.5% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '78',
#   'Attack': '84',
#   'Defense': '78',
#   'Sp. Atk': '109',
#   'Sp. Def': '85',
#   'Speed': '100',
#   'Total': '534'},
#  'Squirtle': {'National №': '007',
#   'Type': '\nWater ',
#   'Species': 'Tiny Turtle Pokémon',
#   'Height': '0.5\xa0m (1′08″)',
#   'Weight': '9.0\xa0kg (19.8\xa0lbs)',
#   'Abilities': '1. TorrentRain Dish (hidden ability)',
#   'Local №': "007 (Red/Blue/Yellow)232 (Gold/Silver/Crystal)007 (FireRed/LeafGreen)237 (HeartGold/SoulSilver)086 (X/Y — Central Kalos)007 (Let's Go Pikachu/Let's Go Eevee)071 (The Isle of Armor)",
#   'EV yield': '\n1 Defense ',
#   'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '63',
#   'Growth Rate': 'Medium Slow',
#   'Egg Groups': 'Monster, Water 1',
#   'Gender': '87.5% male, 12.5% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '44',
#   'Attack': '48',
#   'Defense': '65',
#   'Sp. Atk': '50',
#   'Sp. Def': '64',
#   'Speed': '43',
#   'Total': '314'},
#  'Wartortle': {'National №': '008',
#   'Type': '\nWater ',
#   'Species': 'Turtle Pokémon',
#   'Height': '1.0\xa0m (3′03″)',
#   'Weight': '22.5\xa0kg (49.6\xa0lbs)',
#   'Abilities': '1. TorrentRain Dish (hidden ability)',
#   'Local №': "008 (Red/Blue/Yellow)233 (Gold/Silver/Crystal)008 (FireRed/LeafGreen)238 (HeartGold/SoulSilver)087 (X/Y — Central Kalos)008 (Let's Go Pikachu/Let's Go Eevee)072 (The Isle of Armor)",
#   'EV yield': '\n1 Defense, 1 Special Defense ',
#   'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '142',
#   'Growth Rate': 'Medium Slow',
#   'Egg Groups': 'Monster, Water 1',
#   'Gender': '87.5% male, 12.5% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '59',
#   'Attack': '63',
#   'Defense': '80',
#   'Sp. Atk': '65',
#   'Sp. Def': '80',
#   'Speed': '58',
#   'Total': '405'},
#  'Blastoise': {'National №': '009',
#   'Type': '\nWater ',
#   'Species': 'Shellfish Pokémon',
#   'Height': '1.6\xa0m (5′03″)',
#   'Weight': '85.5\xa0kg (188.5\xa0lbs)',
#   'Abilities': '1. TorrentRain Dish (hidden ability)',
#   'Local №': "009 (Red/Blue/Yellow)234 (Gold/Silver/Crystal)009 (FireRed/LeafGreen)239 (HeartGold/SoulSilver)088 (X/Y — Central Kalos)009 (Let's Go Pikachu/Let's Go Eevee)073 (The Isle of Armor)",
#   'EV yield': '\n3 Special Defense ',
#   'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '239',
#   'Growth Rate': 'Medium Slow',
#   'Egg Groups': 'Monster, Water 1',
#   'Gender': '87.5% male, 12.5% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '79',
#   'Attack': '83',
#   'Defense': '100',
#   'Sp. Atk': '85',
#   'Sp. Def': '105',
#   'Speed': '78',
#   'Total': '530'},
#  'Caterpie': {'National №': '010',
#   'Type': '\nBug ',
#   'Species': 'Worm Pokémon',
#   'Height': '0.3\xa0m (1′00″)',
#   'Weight': '2.9\xa0kg (6.4\xa0lbs)',
#   'Abilities': '1. Shield DustRun Away (hidden ability)',
#   'Local №': "010 (Red/Blue/Yellow)024 (Gold/Silver/Crystal)010 (FireRed/LeafGreen)024 (HeartGold/SoulSilver)023 (X/Y — Central Kalos)017 (Sun/Moon — Alola dex)017 (U.Sun/U.Moon — Alola dex)010 (Let's Go Pikachu/Let's Go Eevee)013 (Sword/Shield)",
#   'EV yield': '\n1 HP ',
#   'Catch rate': '\n255 (33.3% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '39',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Bug',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '15 (3,599–3,855 steps)\n',
#   'HP': '45',
#   'Attack': '30',
#   'Defense': '35',
#   'Sp. Atk': '20',
#   'Sp. Def': '20',
#   'Speed': '45',
#   'Total': '195'},
#  'Metapod': {'National №': '011',
#   'Type': '\nBug ',
#   'Species': 'Cocoon Pokémon',
#   'Height': '0.7\xa0m (2′04″)',
#   'Weight': '9.9\xa0kg (21.8\xa0lbs)',
#   'Abilities': '1. Shed Skin',
#   'Local №': "011 (Red/Blue/Yellow)025 (Gold/Silver/Crystal)011 (FireRed/LeafGreen)025 (HeartGold/SoulSilver)024 (X/Y — Central Kalos)018 (Sun/Moon — Alola dex)018 (U.Sun/U.Moon — Alola dex)011 (Let's Go Pikachu/Let's Go Eevee)014 (Sword/Shield)",
#   'EV yield': '\n2 Defense ',
#   'Catch rate': '\n120 (15.7% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '72',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Bug',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '15 (3,599–3,855 steps)\n',
#   'HP': '50',
#   'Attack': '20',
#   'Defense': '55',
#   'Sp. Atk': '25',
#   'Sp. Def': '25',
#   'Speed': '30',
#   'Total': '205'},
#  'Butterfree': {'National №': '012',
#   'Type': '\nBug Flying ',
#   'Species': 'Butterfly Pokémon',
#   'Height': '1.1\xa0m (3′07″)',
#   'Weight': '32.0\xa0kg (70.5\xa0lbs)',
#   'Abilities': '1. Compound EyesTinted Lens (hidden ability)',
#   'Local №': "012 (Red/Blue/Yellow)026 (Gold/Silver/Crystal)012 (FireRed/LeafGreen)026 (HeartGold/SoulSilver)025 (X/Y — Central Kalos)019 (Sun/Moon — Alola dex)019 (U.Sun/U.Moon — Alola dex)012 (Let's Go Pikachu/Let's Go Eevee)015 (Sword/Shield)",
#   'EV yield': '\n2 Special Attack, 1 Special Defense ',
#   'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '178',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Bug',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '15 (3,599–3,855 steps)\n',
#   'HP': '60',
#   'Attack': '45',
#   'Defense': '50',
#   'Sp. Atk': '90',
#   'Sp. Def': '80',
#   'Speed': '70',
#   'Total': '395'},
#  'Weedle': {'National №': '013',
#   'Type': '\nBug Poison ',
#   'Species': 'Hairy Bug Pokémon',
#   'Height': '0.3\xa0m (1′00″)',
#   'Weight': '3.2\xa0kg (7.1\xa0lbs)',
#   'Abilities': '1. Shield DustRun Away (hidden ability)',
#   'Local №': "013 (Red/Blue/Yellow)027 (Gold/Silver/Crystal)013 (FireRed/LeafGreen)027 (HeartGold/SoulSilver)026 (X/Y — Central Kalos)013 (Let's Go Pikachu/Let's Go Eevee)",
#   'EV yield': '\n1 Speed ',
#   'Catch rate': '\n255 (33.3% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '39',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Bug',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '15 (3,599–3,855 steps)\n',
#   'HP': '40',
#   'Attack': '35',
#   'Defense': '30',
#   'Sp. Atk': '20',
#   'Sp. Def': '20',
#   'Speed': '50',
#   'Total': '195'},
#  'Kakuna': {'National №': '014',
#   'Type': '\nBug Poison ',
#   'Species': 'Cocoon Pokémon',
#   'Height': '0.6\xa0m (2′00″)',
#   'Weight': '10.0\xa0kg (22.0\xa0lbs)',
#   'Abilities': '1. Shed Skin',
#   'Local №': "014 (Red/Blue/Yellow)028 (Gold/Silver/Crystal)014 (FireRed/LeafGreen)028 (HeartGold/SoulSilver)027 (X/Y — Central Kalos)014 (Let's Go Pikachu/Let's Go Eevee)",
#   'EV yield': '\n2 Defense ',
#   'Catch rate': '\n120 (15.7% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '72',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Bug',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '15 (3,599–3,855 steps)\n',
#   'HP': '45',
#   'Attack': '25',
#   'Defense': '50',
#   'Sp. Atk': '25',
#   'Sp. Def': '25',
#   'Speed': '35',
#   'Total': '205'},
#  'Beedrill': {'National №': '015',
#   'Type': '\nBug Poison ',
#   'Species': 'Poison Bee Pokémon',
#   'Height': '1.0\xa0m (3′03″)',
#   'Weight': '29.5\xa0kg (65.0\xa0lbs)',
#   'Abilities': '1. SwarmSniper (hidden ability)',
#   'Local №': "015 (Red/Blue/Yellow)029 (Gold/Silver/Crystal)015 (FireRed/LeafGreen)029 (HeartGold/SoulSilver)028 (X/Y — Central Kalos)015 (Let's Go Pikachu/Let's Go Eevee)",
#   'EV yield': '\n2 Attack, 1 Special Defense ',
#   'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '178',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Bug',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '15 (3,599–3,855 steps)\n',
#   'HP': '65',
#   'Attack': '90',
#   'Defense': '40',
#   'Sp. Atk': '45',
#   'Sp. Def': '80',
#   'Speed': '75',
#   'Total': '395'},
#  'Pidgey': {'National №': '016',
#   'Type': '\nNormal Flying ',
#   'Species': 'Tiny Bird Pokémon',
#   'Height': '0.3\xa0m (1′00″)',
#   'Weight': '1.8\xa0kg (4.0\xa0lbs)',
#   'Abilities': '1. Keen Eye2. Tangled FeetBig Pecks (hidden ability)',
#   'Local №': "016 (Red/Blue/Yellow)010 (Gold/Silver/Crystal)016 (FireRed/LeafGreen)010 (HeartGold/SoulSilver)017 (X/Y — Central Kalos)016 (Let's Go Pikachu/Let's Go Eevee)",
#   'EV yield': '\n1 Speed ',
#   'Catch rate': '\n255 (33.3% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '50',
#   'Growth Rate': 'Medium Slow',
#   'Egg Groups': 'Flying',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '15 (3,599–3,855 steps)\n',
#   'HP': '40',
#   'Attack': '45',
#   'Defense': '40',
#   'Sp. Atk': '35',
#   'Sp. Def': '35',
#   'Speed': '56',
#   'Total': '251'},
#  'Pidgeotto': {'National №': '017',
#   'Type': '\nNormal Flying ',
#   'Species': 'Bird Pokémon',
#   'Height': '1.1\xa0m (3′07″)',
#   'Weight': '30.0\xa0kg (66.1\xa0lbs)',
#   'Abilities': '1. Keen Eye2. Tangled FeetBig Pecks (hidden ability)',
#   'Local №': "017 (Red/Blue/Yellow)011 (Gold/Silver/Crystal)017 (FireRed/LeafGreen)011 (HeartGold/SoulSilver)018 (X/Y — Central Kalos)017 (Let's Go Pikachu/Let's Go Eevee)",
#   'EV yield': '\n2 Speed ',
#   'Catch rate': '\n120 (15.7% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '122',
#   'Growth Rate': 'Medium Slow',
#   'Egg Groups': 'Flying',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '15 (3,599–3,855 steps)\n',
#   'HP': '63',
#   'Attack': '60',
#   'Defense': '55',
#   'Sp. Atk': '50',
#   'Sp. Def': '50',
#   'Speed': '71',
#   'Total': '349'},
#  'Pidgeot': {'National №': '018',
#   'Type': '\nNormal Flying ',
#   'Species': 'Bird Pokémon',
#   'Height': '1.5\xa0m (4′11″)',
#   'Weight': '39.5\xa0kg (87.1\xa0lbs)',
#   'Abilities': '1. Keen Eye2. Tangled FeetBig Pecks (hidden ability)',
#   'Local №': "018 (Red/Blue/Yellow)012 (Gold/Silver/Crystal)018 (FireRed/LeafGreen)012 (HeartGold/SoulSilver)019 (X/Y — Central Kalos)018 (Let's Go Pikachu/Let's Go Eevee)",
#   'EV yield': '\n3 Speed ',
#   'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '216',
#   'Growth Rate': 'Medium Slow',
#   'Egg Groups': 'Flying',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '15 (3,599–3,855 steps)\n',
#   'HP': '83',
#   'Attack': '80',
#   'Defense': '75',
#   'Sp. Atk': '70',
#   'Sp. Def': '70',
#   'Speed': '101',
#   'Total': '479'},
#  'Rattata': {'National №': '019',
#   'Type': '\nNormal ',
#   'Species': 'Mouse Pokémon',
#   'Height': '0.3\xa0m (1′00″)',
#   'Weight': '3.5\xa0kg (7.7\xa0lbs)',
#   'Abilities': '1. Run Away2. GutsHustle (hidden ability)',
#   'Local №': "019 (Red/Blue/Yellow)017 (Gold/Silver/Crystal)019 (FireRed/LeafGreen)017 (HeartGold/SoulSilver)059 (Black 2/White 2)015 (Sun/Moon — Alola dex)015 (U.Sun/U.Moon — Alola dex)019 (Let's Go Pikachu/Let's Go Eevee)",
#   'EV yield': '\n1 Speed ',
#   'Catch rate': '\n255 (33.3% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '51',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Field',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '15 (3,599–3,855 steps)\n',
#   'HP': '30',
#   'Attack': '56',
#   'Defense': '35',
#   'Sp. Atk': '25',
#   'Sp. Def': '35',
#   'Speed': '72',
#   'Total': '253'},
#  'Raticate': {'National №': '020',
#   'Type': '\nNormal ',
#   'Species': 'Mouse Pokémon',
#   'Height': '0.7\xa0m (2′04″)',
#   'Weight': '18.5\xa0kg (40.8\xa0lbs)',
#   'Abilities': '1. Run Away2. GutsHustle (hidden ability)',
#   'Local №': "020 (Red/Blue/Yellow)018 (Gold/Silver/Crystal)020 (FireRed/LeafGreen)018 (HeartGold/SoulSilver)060 (Black 2/White 2)016 (Sun/Moon — Alola dex)016 (U.Sun/U.Moon — Alola dex)020 (Let's Go Pikachu/Let's Go Eevee)",
#   'EV yield': '\n2 Speed ',
#   'Catch rate': '\n127 (16.6% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '145',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Field',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '15 (3,599–3,855 steps)\n',
#   'HP': '55',
#   'Attack': '81',
#   'Defense': '60',
#   'Sp. Atk': '50',
#   'Sp. Def': '70',
#   'Speed': '97',
#   'Total': '413'},
#  'Spearow': {'National №': '021',
#   'Type': '\nNormal Flying ',
#   'Species': 'Tiny Bird Pokémon',
#   'Height': '0.3\xa0m (1′00″)',
#   'Weight': '2.0\xa0kg (4.4\xa0lbs)',
#   'Abilities': '1. Keen EyeSniper (hidden ability)',
#   'Local №': "021 (Red/Blue/Yellow)013 (Gold/Silver/Crystal)021 (FireRed/LeafGreen)013 (HeartGold/SoulSilver)109 (X/Y — Mountain Kalos)073 (Sun/Moon — Alola dex)087 (U.Sun/U.Moon — Alola dex)021 (Let's Go Pikachu/Let's Go Eevee)",
#   'EV yield': '\n1 Speed ',
#   'Catch rate': '\n255 (33.3% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '52',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Flying',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '15 (3,599–3,855 steps)\n',
#   'HP': '40',
#   'Attack': '60',
#   'Defense': '30',
#   'Sp. Atk': '31',
#   'Sp. Def': '31',
#   'Speed': '70',
#   'Total': '262'},
#  'Fearow': {'National №': '022',
#   'Type': '\nNormal Flying ',
#   'Species': 'Beak Pokémon',
#   'Height': '1.2\xa0m (3′11″)',
#   'Weight': '38.0\xa0kg (83.8\xa0lbs)',
#   'Abilities': '1. Keen EyeSniper (hidden ability)',
#   'Local №': "022 (Red/Blue/Yellow)014 (Gold/Silver/Crystal)022 (FireRed/LeafGreen)014 (HeartGold/SoulSilver)110 (X/Y — Mountain Kalos)074 (Sun/Moon — Alola dex)088 (U.Sun/U.Moon — Alola dex)022 (Let's Go Pikachu/Let's Go Eevee)",
#   'EV yield': '\n2 Speed ',
#   'Catch rate': '\n90 (11.8% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '155',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Flying',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '15 (3,599–3,855 steps)\n',
#   'HP': '65',
#   'Attack': '90',
#   'Defense': '65',
#   'Sp. Atk': '61',
#   'Sp. Def': '61',
#   'Speed': '100',
#   'Total': '442'},
#  'Ekans': {'National №': '023',
#   'Type': '\nPoison ',
#   'Species': 'Snake Pokémon',
#   'Height': '2.0\xa0m (6′07″)',
#   'Weight': '6.9\xa0kg (15.2\xa0lbs)',
#   'Abilities': '1. Intimidate2. Shed SkinUnnerve (hidden ability)',
#   'Local №': "023 (Red/Blue/Yellow)050 (Gold/Silver/Crystal)023 (FireRed/LeafGreen)050 (HeartGold/SoulSilver)037 (X/Y — Mountain Kalos)061 (U.Sun/U.Moon — Alola dex)023 (Let's Go Pikachu/Let's Go Eevee)",
#   'EV yield': '\n1 Attack ',
#   'Catch rate': '\n255 (33.3% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '58',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Dragon, Field',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '35',
#   'Attack': '60',
#   'Defense': '44',
#   'Sp. Atk': '40',
#   'Sp. Def': '54',
#   'Speed': '55',
#   'Total': '288'},
#  'Arbok': {'National №': '024',
#   'Type': '\nPoison ',
#   'Species': 'Cobra Pokémon',
#   'Height': '3.5\xa0m (11′06″)',
#   'Weight': '65.0\xa0kg (143.3\xa0lbs)',
#   'Abilities': '1. Intimidate2. Shed SkinUnnerve (hidden ability)',
#   'Local №': "024 (Red/Blue/Yellow)051 (Gold/Silver/Crystal)024 (FireRed/LeafGreen)051 (HeartGold/SoulSilver)038 (X/Y — Mountain Kalos)062 (U.Sun/U.Moon — Alola dex)024 (Let's Go Pikachu/Let's Go Eevee)",
#   'EV yield': '\n2 Attack ',
#   'Catch rate': '\n90 (11.8% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '157',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Dragon, Field',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '60',
#   'Attack': '95',
#   'Defense': '69',
#   'Sp. Atk': '65',
#   'Sp. Def': '79',
#   'Speed': '80',
#   'Total': '448'},
#  'Pikachu': {'National №': '025',
#   'Type': '\nElectric ',
#   'Species': 'Mouse Pokémon',
#   'Height': '0.4\xa0m (1′04″)',
#   'Weight': '6.0\xa0kg (13.2\xa0lbs)',
#   'Abilities': '1. StaticLightning Rod (hidden ability)',
#   'Local №': "025 (Yellow/Red/Blue)022 (Gold/Silver/Crystal)156 (Ruby/Sapphire/Emerald)025 (FireRed/LeafGreen)104 (Diamond/Pearl)104 (Platinum)022 (HeartGold/SoulSilver)036 (X/Y — Central Kalos)163 (Omega Ruby/Alpha Sapphire)025 (Sun/Moon — Alola dex)032 (U.Sun/U.Moon — Alola dex)025 (Let's Go Pikachu/Let's Go Eevee)194 (Sword/Shield)085 (The Isle of Armor)",
#   'EV yield': '\n2 Speed ',
#   'Catch rate': '\n190 (24.8% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '112',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Fairy, Field',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '10 (2,314–2,570 steps)\n',
#   'HP': '35',
#   'Attack': '55',
#   'Defense': '40',
#   'Sp. Atk': '50',
#   'Sp. Def': '50',
#   'Speed': '90',
#   'Total': '320'},
#  'Raichu': {'National №': '026',
#   'Type': '\nElectric ',
#   'Species': 'Mouse Pokémon',
#   'Height': '0.8\xa0m (2′07″)',
#   'Weight': '30.0\xa0kg (66.1\xa0lbs)',
#   'Abilities': '1. StaticLightning Rod (hidden ability)',
#   'Local №': "026 (Yellow/Red/Blue)023 (Gold/Silver/Crystal)157 (Ruby/Sapphire/Emerald)026 (FireRed/LeafGreen)105 (Diamond/Pearl)105 (Platinum)023 (HeartGold/SoulSilver)037 (X/Y — Central Kalos)164 (Omega Ruby/Alpha Sapphire)026 (Sun/Moon — Alola dex)033 (U.Sun/U.Moon — Alola dex)026 (Let's Go Pikachu/Let's Go Eevee)195 (Sword/Shield)086 (The Isle of Armor)",
#   'EV yield': '\n3 Speed ',
#   'Catch rate': '\n75 (9.8% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '218',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Fairy, Field',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '10 (2,314–2,570 steps)\n',
#   'HP': '60',
#   'Attack': '90',
#   'Defense': '55',
#   'Sp. Atk': '90',
#   'Sp. Def': '80',
#   'Speed': '110',
#   'Total': '485'},
#  'Sandshrew': {'National №': '027',
#   'Type': '\nGround ',
#   'Species': 'Mouse Pokémon',
#   'Height': '0.6\xa0m (2′00″)',
#   'Weight': '12.0\xa0kg (26.5\xa0lbs)',
#   'Abilities': '1. Sand VeilSand Rush (hidden ability)',
#   'Local №': "027 (Red/Blue/Yellow)048 (Gold/Silver/Crystal)112 (Ruby/Sapphire/Emerald)027 (FireRed/LeafGreen)048 (HeartGold/SoulSilver)113 (Black 2/White 2)097 (X/Y — Mountain Kalos)117 (Omega Ruby/Alpha Sapphire)251 (Sun/Moon — Alola dex)328 (U.Sun/U.Moon — Alola dex)027 (Let's Go Pikachu/Let's Go Eevee)168 (The Isle of Armor)",
#   'EV yield': '\n1 Defense ',
#   'Catch rate': '\n255 (33.3% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '60',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Field',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '50',
#   'Attack': '75',
#   'Defense': '85',
#   'Sp. Atk': '20',
#   'Sp. Def': '30',
#   'Speed': '40',
#   'Total': '300'},
#  'Sandslash': {'National №': '028',
#   'Type': '\nGround ',
#   'Species': 'Mouse Pokémon',
#   'Height': '1.0\xa0m (3′03″)',
#   'Weight': '29.5\xa0kg (65.0\xa0lbs)',
#   'Abilities': '1. Sand VeilSand Rush (hidden ability)',
#   'Local №': "028 (Red/Blue/Yellow)049 (Gold/Silver/Crystal)113 (Ruby/Sapphire/Emerald)028 (FireRed/LeafGreen)049 (HeartGold/SoulSilver)114 (Black 2/White 2)098 (X/Y — Mountain Kalos)118 (Omega Ruby/Alpha Sapphire)252 (Sun/Moon — Alola dex)329 (U.Sun/U.Moon — Alola dex)028 (Let's Go Pikachu/Let's Go Eevee)169 (The Isle of Armor)",
#   'EV yield': '\n2 Defense ',
#   'Catch rate': '\n90 (11.8% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '158',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Field',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '75',
#   'Attack': '100',
#   'Defense': '110',
#   'Sp. Atk': '45',
#   'Sp. Def': '55',
#   'Speed': '65',
#   'Total': '450'},
#  'Nidoran♀': {'National №': '029',
#   'Type': '\nPoison ',
#   'Species': 'Poison Pin Pokémon',
#   'Height': '0.4\xa0m (1′04″)',
#   'Weight': '7.0\xa0kg (15.4\xa0lbs)',
#   'Abilities': '1. Poison Point2. RivalryHustle (hidden ability)',
#   'Local №': "029 (Red/Blue/Yellow)095 (Gold/Silver/Crystal)029 (FireRed/LeafGreen)095 (HeartGold/SoulSilver)104 (X/Y — Coastal Kalos)029 (Let's Go Pikachu/Let's Go Eevee)065 (The Crown Tundra)",
#   'EV yield': '\n1 HP ',
#   'Catch rate': '\n235 (30.7% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '55',
#   'Growth Rate': 'Medium Slow',
#   'Egg Groups': 'Field, Monster',
#   'Gender': '0% male, 100% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '55',
#   'Attack': '47',
#   'Defense': '52',
#   'Sp. Atk': '40',
#   'Sp. Def': '40',
#   'Speed': '41',
#   'Total': '275'},
#  'Nidorina': {'National №': '030',
#   'Type': '\nPoison ',
#   'Species': 'Poison Pin Pokémon',
#   'Height': '0.8\xa0m (2′07″)',
#   'Weight': '20.0\xa0kg (44.1\xa0lbs)',
#   'Abilities': '1. Poison Point2. RivalryHustle (hidden ability)',
#   'Local №': "030 (Red/Blue/Yellow)096 (Gold/Silver/Crystal)030 (FireRed/LeafGreen)096 (HeartGold/SoulSilver)105 (X/Y — Coastal Kalos)030 (Let's Go Pikachu/Let's Go Eevee)066 (The Crown Tundra)",
#   'EV yield': '\n2 HP ',
#   'Catch rate': '\n120 (15.7% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '128',
#   'Growth Rate': 'Medium Slow',
#   'Egg Groups': 'Undiscovered',
#   'Gender': '0% male, 100% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '70',
#   'Attack': '62',
#   'Defense': '67',
#   'Sp. Atk': '55',
#   'Sp. Def': '55',
#   'Speed': '56',
#   'Total': '365'},
#  'Nidoqueen': {'National №': '031',
#   'Type': '\nPoison Ground ',
#   'Species': 'Drill Pokémon',
#   'Height': '1.3\xa0m (4′03″)',
#   'Weight': '60.0\xa0kg (132.3\xa0lbs)',
#   'Abilities': '1. Poison Point2. RivalrySheer Force (hidden ability)',
#   'Local №': "031 (Red/Blue/Yellow)097 (Gold/Silver/Crystal)031 (FireRed/LeafGreen)097 (HeartGold/SoulSilver)106 (X/Y — Coastal Kalos)031 (Let's Go Pikachu/Let's Go Eevee)067 (The Crown Tundra)",
#   'EV yield': '\n3 HP ',
#   'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '227',
#   'Growth Rate': 'Medium Slow',
#   'Egg Groups': 'Undiscovered',
#   'Gender': '0% male, 100% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '90',
#   'Attack': '92',
#   'Defense': '87',
#   'Sp. Atk': '75',
#   'Sp. Def': '85',
#   'Speed': '76',
#   'Total': '505'},
#  'Nidoran♂': {'National №': '032',
#   'Type': '\nPoison ',
#   'Species': 'Poison Pin Pokémon',
#   'Height': '0.5\xa0m (1′08″)',
#   'Weight': '9.0\xa0kg (19.8\xa0lbs)',
#   'Abilities': '1. Poison Point2. RivalryHustle (hidden ability)',
#   'Local №': "032 (Red/Blue/Yellow)098 (Gold/Silver/Crystal)032 (FireRed/LeafGreen)098 (HeartGold/SoulSilver)107 (X/Y — Coastal Kalos)032 (Let's Go Pikachu/Let's Go Eevee)068 (The Crown Tundra)",
#   'EV yield': '\n1 Attack ',
#   'Catch rate': '\n235 (30.7% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '55',
#   'Growth Rate': 'Medium Slow',
#   'Egg Groups': 'Field, Monster',
#   'Gender': '100% male, 0% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '46',
#   'Attack': '57',
#   'Defense': '40',
#   'Sp. Atk': '40',
#   'Sp. Def': '40',
#   'Speed': '50',
#   'Total': '273'},
#  'Nidorino': {'National №': '033',
#   'Type': '\nPoison ',
#   'Species': 'Poison Pin Pokémon',
#   'Height': '0.9\xa0m (2′11″)',
#   'Weight': '19.5\xa0kg (43.0\xa0lbs)',
#   'Abilities': '1. Poison Point2. RivalryHustle (hidden ability)',
#   'Local №': "033 (Red/Blue/Yellow)099 (Gold/Silver/Crystal)033 (FireRed/LeafGreen)099 (HeartGold/SoulSilver)108 (X/Y — Coastal Kalos)033 (Let's Go Pikachu/Let's Go Eevee)069 (The Crown Tundra)",
#   'EV yield': '\n2 Attack ',
#   'Catch rate': '\n120 (15.7% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '128',
#   'Growth Rate': 'Medium Slow',
#   'Egg Groups': 'Field, Monster',
#   'Gender': '100% male, 0% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '61',
#   'Attack': '72',
#   'Defense': '57',
#   'Sp. Atk': '55',
#   'Sp. Def': '55',
#   'Speed': '65',
#   'Total': '365'},
#  'Nidoking': {'National №': '034',
#   'Type': '\nPoison Ground ',
#   'Species': 'Drill Pokémon',
#   'Height': '1.4\xa0m (4′07″)',
#   'Weight': '62.0\xa0kg (136.7\xa0lbs)',
#   'Abilities': '1. Poison Point2. RivalrySheer Force (hidden ability)',
#   'Local №': "034 (Red/Blue/Yellow)100 (Gold/Silver/Crystal)034 (FireRed/LeafGreen)100 (HeartGold/SoulSilver)109 (X/Y — Coastal Kalos)034 (Let's Go Pikachu/Let's Go Eevee)070 (The Crown Tundra)",
#   'EV yield': '\n3 Attack ',
#   'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '227',
#   'Growth Rate': 'Medium Slow',
#   'Egg Groups': 'Field, Monster',
#   'Gender': '100% male, 0% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '81',
#   'Attack': '102',
#   'Defense': '77',
#   'Sp. Atk': '85',
#   'Sp. Def': '75',
#   'Speed': '85',
#   'Total': '505'},
#  'Clefairy': {'National №': '035',
#   'Type': '\nFairy ',
#   'Species': 'Fairy Pokémon',
#   'Height': '0.6\xa0m (2′00″)',
#   'Weight': '7.5\xa0kg (16.5\xa0lbs)',
#   'Abilities': '1. Cute Charm2. Magic GuardFriend Guard (hidden ability)',
#   'Local №': "035 (Red/Blue/Yellow)041 (Gold/Silver/Crystal)035 (FireRed/LeafGreen)100 (Diamond/Pearl)100 (Platinum)041 (HeartGold/SoulSilver)089 (Black 2/White 2)211 (Sun/Moon — Alola dex)273 (U.Sun/U.Moon — Alola dex)035 (Let's Go Pikachu/Let's Go Eevee)255 (Sword/Shield)044 (The Crown Tundra)",
#   'EV yield': '\n2 HP ',
#   'Catch rate': '\n150 (19.6% with PokéBall, full HP)\n',
#   None: '\n140 (higher than normal)\n',
#   'Base Exp.': '113',
#   'Growth Rate': 'Fast',
#   'Egg Groups': 'Fairy',
#   'Gender': '25% male, 75% female',
#   'Egg cycles': '10 (2,314–2,570 steps)\n',
#   'HP': '70',
#   'Attack': '45',
#   'Defense': '48',
#   'Sp. Atk': '60',
#   'Sp. Def': '65',
#   'Speed': '35',
#   'Total': '323'},
#  'Clefable': {'National №': '036',
#   'Type': '\nFairy ',
#   'Species': 'Fairy Pokémon',
#   'Height': '1.3\xa0m (4′03″)',
#   'Weight': '40.0\xa0kg (88.2\xa0lbs)',
#   'Abilities': '1. Cute Charm2. Magic GuardUnaware (hidden ability)',
#   'Local №': "036 (Red/Blue/Yellow)042 (Gold/Silver/Crystal)036 (FireRed/LeafGreen)101 (Diamond/Pearl)101 (Platinum)042 (HeartGold/SoulSilver)090 (Black 2/White 2)212 (Sun/Moon — Alola dex)274 (U.Sun/U.Moon — Alola dex)036 (Let's Go Pikachu/Let's Go Eevee)256 (Sword/Shield)045 (The Crown Tundra)",
#   'EV yield': '\n3 HP ',
#   'Catch rate': '\n25 (3.3% with PokéBall, full HP)\n',
#   None: '\n140 (higher than normal)\n',
#   'Base Exp.': '217',
#   'Growth Rate': 'Fast',
#   'Egg Groups': 'Fairy',
#   'Gender': '25% male, 75% female',
#   'Egg cycles': '10 (2,314–2,570 steps)\n',
#   'HP': '95',
#   'Attack': '70',
#   'Defense': '73',
#   'Sp. Atk': '95',
#   'Sp. Def': '90',
#   'Speed': '60',
#   'Total': '483'},
#  'Vulpix': {'National №': '037',
#   'Type': '\nFire ',
#   'Species': 'Fox Pokémon',
#   'Height': '0.6\xa0m (2′00″)',
#   'Weight': '9.9\xa0kg (21.8\xa0lbs)',
#   'Abilities': '1. Flash FireDrought (hidden ability)',
#   'Local №': "037 (Red/Blue/Yellow)125 (Gold/Silver/Crystal)153 (Ruby/Sapphire/Emerald)037 (FireRed/LeafGreen)127 (HeartGold/SoulSilver)248 (Black 2/White 2)160 (Omega Ruby/Alpha Sapphire)253 (Sun/Moon — Alola dex)330 (U.Sun/U.Moon — Alola dex)037 (Let's Go Pikachu/Let's Go Eevee)068 (Sword/Shield)",
#   'EV yield': '\n1 Speed ',
#   'Catch rate': '\n190 (24.8% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '60',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Field',
#   'Gender': '25% male, 75% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '38',
#   'Attack': '41',
#   'Defense': '40',
#   'Sp. Atk': '50',
#   'Sp. Def': '65',
#   'Speed': '65',
#   'Total': '299'},
#  'Ninetales': {'National №': '038',
#   'Type': '\nFire ',
#   'Species': 'Fox Pokémon',
#   'Height': '1.1\xa0m (3′07″)',
#   'Weight': '19.9\xa0kg (43.9\xa0lbs)',
#   'Abilities': '1. Flash FireDrought (hidden ability)',
#   'Local №': "038 (Red/Blue/Yellow)126 (Gold/Silver/Crystal)154 (Ruby/Sapphire/Emerald)038 (FireRed/LeafGreen)128 (HeartGold/SoulSilver)249 (Black 2/White 2)161 (Omega Ruby/Alpha Sapphire)254 (Sun/Moon — Alola dex)331 (U.Sun/U.Moon — Alola dex)038 (Let's Go Pikachu/Let's Go Eevee)069 (Sword/Shield)",
#   'EV yield': '\n1 Special Defense, 1 Speed ',
#   'Catch rate': '\n75 (9.8% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '177',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Field',
#   'Gender': '25% male, 75% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '73',
#   'Attack': '76',
#   'Defense': '75',
#   'Sp. Atk': '81',
#   'Sp. Def': '100',
#   'Speed': '100',
#   'Total': '505'},
#  'Jigglypuff': {'National №': '039',
#   'Type': '\nNormal Fairy ',
#   'Species': 'Balloon Pokémon',
#   'Height': '0.5\xa0m (1′08″)',
#   'Weight': '5.5\xa0kg (12.1\xa0lbs)',
#   'Abilities': '1. Cute Charm2. CompetitiveFriend Guard (hidden ability)',
#   'Local №': "039 (Red/Blue/Yellow)044 (Gold/Silver/Crystal)138 (Ruby/Sapphire/Emerald)039 (FireRed/LeafGreen)044 (HeartGold/SoulSilver)282 (Black 2/White 2)120 (X/Y — Mountain Kalos)143 (Omega Ruby/Alpha Sapphire)135 (Sun/Moon — Alola dex)168 (U.Sun/U.Moon — Alola dex)039 (Let's Go Pikachu/Let's Go Eevee)012 (The Isle of Armor)",
#   'EV yield': '\n2 HP ',
#   'Catch rate': '\n170 (22.2% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '95',
#   'Growth Rate': 'Fast',
#   'Egg Groups': 'Fairy',
#   'Gender': '25% male, 75% female',
#   'Egg cycles': '10 (2,314–2,570 steps)\n',
#   'HP': '115',
#   'Attack': '45',
#   'Defense': '20',
#   'Sp. Atk': '45',
#   'Sp. Def': '25',
#   'Speed': '20',
#   'Total': '270'},
#  'Wigglytuff': {'National №': '040',
#   'Type': '\nNormal Fairy ',
#   'Species': 'Balloon Pokémon',
#   'Height': '1.0\xa0m (3′03″)',
#   'Weight': '12.0\xa0kg (26.5\xa0lbs)',
#   'Abilities': '1. Cute Charm2. CompetitiveFrisk (hidden ability)',
#   'Local №': "040 (Red/Blue/Yellow)045 (Gold/Silver/Crystal)139 (Ruby/Sapphire/Emerald)040 (FireRed/LeafGreen)045 (HeartGold/SoulSilver)283 (Black 2/White 2)121 (X/Y — Mountain Kalos)144 (Omega Ruby/Alpha Sapphire)136 (Sun/Moon — Alola dex)169 (U.Sun/U.Moon — Alola dex)040 (Let's Go Pikachu/Let's Go Eevee)013 (The Isle of Armor)",
#   'EV yield': '\n3 HP ',
#   'Catch rate': '\n50 (6.5% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '196',
#   'Growth Rate': 'Fast',
#   'Egg Groups': 'Fairy',
#   'Gender': '25% male, 75% female',
#   'Egg cycles': '10 (2,314–2,570 steps)\n',
#   'HP': '140',
#   'Attack': '70',
#   'Defense': '45',
#   'Sp. Atk': '85',
#   'Sp. Def': '50',
#   'Speed': '45',
#   'Total': '435'},
#  'Zubat': {'National №': '041',
#   'Type': '\nPoison Flying ',
#   'Species': 'Bat Pokémon',
#   'Height': '0.8\xa0m (2′07″)',
#   'Weight': '7.5\xa0kg (16.5\xa0lbs)',
#   'Abilities': '1. Inner FocusInfiltrator (hidden ability)',
#   'Local №': "041 (Yellow/Red/Blue)037 (Gold/Silver/Crystal)063 (Ruby/Sapphire/Emerald)041 (FireRed/LeafGreen)028 (Diamond/Pearl)028 (Platinum)037 (HeartGold/SoulSilver)061 (Black 2/White 2)145 (X/Y — Central Kalos)065 (Omega Ruby/Alpha Sapphire)068 (Sun/Moon — Alola dex)080 (U.Sun/U.Moon — Alola dex)041 (Let's Go Pikachu/Let's Go Eevee)144 (The Crown Tundra)",
#   'EV yield': '\n1 Speed ',
#   'Catch rate': '\n255 (33.3% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '49',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Flying',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '15 (3,599–3,855 steps)\n',
#   'HP': '40',
#   'Attack': '45',
#   'Defense': '35',
#   'Sp. Atk': '30',
#   'Sp. Def': '40',
#   'Speed': '55',
#   'Total': '245'},
#  'Golbat': {'National №': '042',
#   'Type': '\nPoison Flying ',
#   'Species': 'Bat Pokémon',
#   'Height': '1.6\xa0m (5′03″)',
#   'Weight': '55.0\xa0kg (121.3\xa0lbs)',
#   'Abilities': '1. Inner FocusInfiltrator (hidden ability)',
#   'Local №': "042 (Yellow/Red/Blue)038 (Gold/Silver/Crystal)064 (Ruby/Sapphire/Emerald)042 (FireRed/LeafGreen)029 (Diamond/Pearl)029 (Platinum)038 (HeartGold/SoulSilver)062 (Black 2/White 2)146 (X/Y — Central Kalos)066 (Omega Ruby/Alpha Sapphire)069 (Sun/Moon — Alola dex)081 (U.Sun/U.Moon — Alola dex)042 (Let's Go Pikachu/Let's Go Eevee)145 (The Crown Tundra)",
#   'EV yield': '\n2 Speed ',
#   'Catch rate': '\n90 (11.8% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '159',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Flying',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '15 (3,599–3,855 steps)\n',
#   'HP': '75',
#   'Attack': '80',
#   'Defense': '70',
#   'Sp. Atk': '65',
#   'Sp. Def': '75',
#   'Speed': '90',
#   'Total': '455'},
#  'Oddish': {'National №': '043',
#   'Type': '\nGrass Poison ',
#   'Species': 'Weed Pokémon',
#   'Height': '0.5\xa0m (1′08″)',
#   'Weight': '5.4\xa0kg (11.9\xa0lbs)',
#   'Abilities': '1. ChlorophyllRun Away (hidden ability)',
#   'Local №': "043 (Red/Blue/Yellow)083 (Gold/Silver/Crystal)088 (Ruby/Sapphire/Emerald)043 (FireRed/LeafGreen)083 (HeartGold/SoulSilver)105 (X/Y — Central Kalos)091 (Omega Ruby/Alpha Sapphire)043 (Let's Go Pikachu/Let's Go Eevee)055 (Sword/Shield)",
#   'EV yield': '\n1 Special Attack ',
#   'Catch rate': '\n255 (33.3% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '64',
#   'Growth Rate': 'Medium Slow',
#   'Egg Groups': 'Grass',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '45',
#   'Attack': '50',
#   'Defense': '55',
#   'Sp. Atk': '75',
#   'Sp. Def': '65',
#   'Speed': '30',
#   'Total': '320'},
#  'Gloom': {'National №': '044',
#   'Type': '\nGrass Poison ',
#   'Species': 'Weed Pokémon',
#   'Height': '0.8\xa0m (2′07″)',
#   'Weight': '8.6\xa0kg (19.0\xa0lbs)',
#   'Abilities': '1. ChlorophyllStench (hidden ability)',
#   'Local №': "044 (Red/Blue/Yellow)084 (Gold/Silver/Crystal)089 (Ruby/Sapphire/Emerald)044 (FireRed/LeafGreen)084 (HeartGold/SoulSilver)106 (X/Y — Central Kalos)092 (Omega Ruby/Alpha Sapphire)044 (Let's Go Pikachu/Let's Go Eevee)056 (Sword/Shield)",
#   'EV yield': '\n2 Special Attack ',
#   'Catch rate': '\n120 (15.7% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '138',
#   'Growth Rate': 'Medium Slow',
#   'Egg Groups': 'Grass',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '60',
#   'Attack': '65',
#   'Defense': '70',
#   'Sp. Atk': '85',
#   'Sp. Def': '75',
#   'Speed': '40',
#   'Total': '395'},
#  'Vileplume': {'National №': '045',
#   'Type': '\nGrass Poison ',
#   'Species': 'Flower Pokémon',
#   'Height': '1.2\xa0m (3′11″)',
#   'Weight': '18.6\xa0kg (41.0\xa0lbs)',
#   'Abilities': '1. ChlorophyllEffect Spore (hidden ability)',
#   'Local №': "045 (Red/Blue/Yellow)085 (Gold/Silver/Crystal)090 (Ruby/Sapphire/Emerald)045 (FireRed/LeafGreen)085 (HeartGold/SoulSilver)107 (X/Y — Central Kalos)093 (Omega Ruby/Alpha Sapphire)045 (Let's Go Pikachu/Let's Go Eevee)057 (Sword/Shield)",
#   'EV yield': '\n3 Special Attack ',
#   'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '221',
#   'Growth Rate': 'Medium Slow',
#   'Egg Groups': 'Grass',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '75',
#   'Attack': '80',
#   'Defense': '85',
#   'Sp. Atk': '110',
#   'Sp. Def': '90',
#   'Speed': '50',
#   'Total': '490'},
#  'Paras': {'National №': '046',
#   'Type': '\nBug Grass ',
#   'Species': 'Mushroom Pokémon',
#   'Height': '0.3\xa0m (1′00″)',
#   'Weight': '5.4\xa0kg (11.9\xa0lbs)',
#   'Abilities': '1. Effect Spore2. Dry SkinDamp (hidden ability)',
#   'Local №': "046 (Red/Blue/Yellow)070 (Gold/Silver/Crystal)046 (FireRed/LeafGreen)070 (HeartGold/SoulSilver)147 (Sun/Moon — Alola dex)180 (U.Sun/U.Moon — Alola dex)046 (Let's Go Pikachu/Let's Go Eevee)",
#   'EV yield': '\n1 Attack ',
#   'Catch rate': '\n190 (24.8% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '57',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Bug, Grass',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '35',
#   'Attack': '70',
#   'Defense': '55',
#   'Sp. Atk': '45',
#   'Sp. Def': '55',
#   'Speed': '25',
#   'Total': '285'},
#  'Parasect': {'National №': '047',
#   'Type': '\nBug Grass ',
#   'Species': 'Mushroom Pokémon',
#   'Height': '1.0\xa0m (3′03″)',
#   'Weight': '29.5\xa0kg (65.0\xa0lbs)',
#   'Abilities': '1. Effect Spore2. Dry SkinDamp (hidden ability)',
#   'Local №': "047 (Red/Blue/Yellow)071 (Gold/Silver/Crystal)047 (FireRed/LeafGreen)071 (HeartGold/SoulSilver)148 (Sun/Moon — Alola dex)181 (U.Sun/U.Moon — Alola dex)047 (Let's Go Pikachu/Let's Go Eevee)",
#   'EV yield': '\n2 Attack, 1 Defense ',
#   'Catch rate': '\n75 (9.8% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '142',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Bug, Grass',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '60',
#   'Attack': '95',
#   'Defense': '80',
#   'Sp. Atk': '60',
#   'Sp. Def': '80',
#   'Speed': '30',
#   'Total': '405'},
#  'Venonat': {'National №': '048',
#   'Type': '\nBug Poison ',
#   'Species': 'Insect Pokémon',
#   'Height': '1.0\xa0m (3′03″)',
#   'Weight': '30.0\xa0kg (66.1\xa0lbs)',
#   'Abilities': '1. Compound Eyes2. Tinted LensRun Away (hidden ability)',
#   'Local №': "048 (Red/Blue/Yellow)108 (Gold/Silver/Crystal)048 (FireRed/LeafGreen)109 (HeartGold/SoulSilver)048 (Let's Go Pikachu/Let's Go Eevee)",
#   'EV yield': '\n1 Special Defense ',
#   'Catch rate': '\n190 (24.8% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '61',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Bug',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '60',
#   'Attack': '55',
#   'Defense': '50',
#   'Sp. Atk': '40',
#   'Sp. Def': '55',
#   'Speed': '45',
#   'Total': '305'},
#  'Venomoth': {'National №': '049',
#   'Type': '\nBug Poison ',
#   'Species': 'Poison Moth Pokémon',
#   'Height': '1.5\xa0m (4′11″)',
#   'Weight': '12.5\xa0kg (27.6\xa0lbs)',
#   'Abilities': '1. Shield Dust2. Tinted LensWonder Skin (hidden ability)',
#   'Local №': "049 (Red/Blue/Yellow)109 (Gold/Silver/Crystal)049 (FireRed/LeafGreen)110 (HeartGold/SoulSilver)049 (Let's Go Pikachu/Let's Go Eevee)",
#   'EV yield': '\n1 Special Attack, 1 Speed ',
#   'Catch rate': '\n75 (9.8% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '158',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Bug',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '70',
#   'Attack': '65',
#   'Defense': '60',
#   'Sp. Atk': '90',
#   'Sp. Def': '75',
#   'Speed': '90',
#   'Total': '450'},
#  'Diglett': {'National №': '050',
#   'Type': '\nGround ',
#   'Species': 'Mole Pokémon',
#   'Height': '0.2\xa0m (0′08″)',
#   'Weight': '0.8\xa0kg (1.8\xa0lbs)',
#   'Abilities': '1. Sand Veil2. Arena TrapSand Force (hidden ability)',
#   'Local №': "050 (Red/Blue/Yellow)132 (Gold/Silver/Crystal)050 (FireRed/LeafGreen)134 (HeartGold/SoulSilver)001 (X/Y — Mountain Kalos)071 (Sun/Moon — Alola dex)085 (U.Sun/U.Moon — Alola dex)050 (Let's Go Pikachu/Let's Go Eevee)164 (Sword/Shield)",
#   'EV yield': '\n1 Speed ',
#   'Catch rate': '\n255 (33.3% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '53',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Field',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '10',
#   'Attack': '55',
#   'Defense': '25',
#   'Sp. Atk': '35',
#   'Sp. Def': '45',
#   'Speed': '95',
#   'Total': '265'},
#  'Dugtrio': {'National №': '051',
#   'Type': '\nGround ',
#   'Species': 'Mole Pokémon',
#   'Height': '0.7\xa0m (2′04″)',
#   'Weight': '33.3\xa0kg (73.4\xa0lbs)',
#   'Abilities': '1. Sand Veil2. Arena TrapSand Force (hidden ability)',
#   'Local №': "051 (Red/Blue/Yellow)133 (Gold/Silver/Crystal)051 (FireRed/LeafGreen)135 (HeartGold/SoulSilver)002 (X/Y — Mountain Kalos)072 (Sun/Moon — Alola dex)086 (U.Sun/U.Moon — Alola dex)051 (Let's Go Pikachu/Let's Go Eevee)165 (Sword/Shield)",
#   'EV yield': '\n2 Speed ',
#   'Catch rate': '\n50 (6.5% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '149',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Field',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '35',
#   'Attack': '100',
#   'Defense': '50',
#   'Sp. Atk': '50',
#   'Sp. Def': '70',
#   'Speed': '120',
#   'Total': '425'},
#  'Meowth': {'National №': '052',
#   'Type': '\nNormal ',
#   'Species': 'Scratch Cat Pokémon',
#   'Height': '0.4\xa0m (1′04″)',
#   'Weight': '4.2\xa0kg (9.3\xa0lbs)',
#   'Abilities': '1. Pickup2. TechnicianUnnerve (hidden ability)',
#   'Local №': "052 (Red/Blue/Yellow)136 (Gold/Silver/Crystal)052 (FireRed/LeafGreen)138 (HeartGold/SoulSilver)045 (Sun/Moon — Alola dex)052 (U.Sun/U.Moon — Alola dex)052 (Let's Go Pikachu/Let's Go Eevee)182 (Sword/Shield)",
#   'EV yield': '\n1 Speed ',
#   'Catch rate': '\n255 (33.3% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '58',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Field',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '40',
#   'Attack': '45',
#   'Defense': '35',
#   'Sp. Atk': '40',
#   'Sp. Def': '40',
#   'Speed': '90',
#   'Total': '290'},
#  'Persian': {'National №': '053',
#   'Type': '\nNormal ',
#   'Species': 'Classy Cat Pokémon',
#   'Height': '1.0\xa0m (3′03″)',
#   'Weight': '32.0\xa0kg (70.5\xa0lbs)',
#   'Abilities': '1. Limber2. TechnicianUnnerve (hidden ability)',
#   'Local №': "053 (Red/Blue/Yellow)137 (Gold/Silver/Crystal)053 (FireRed/LeafGreen)139 (HeartGold/SoulSilver)046 (Sun/Moon — Alola dex)053 (U.Sun/U.Moon — Alola dex)053 (Let's Go Pikachu/Let's Go Eevee)184 (Sword/Shield)",
#   'EV yield': '\n2 Speed ',
#   'Catch rate': '\n90 (11.8% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '154',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Field',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '65',
#   'Attack': '70',
#   'Defense': '60',
#   'Sp. Atk': '65',
#   'Sp. Def': '65',
#   'Speed': '115',
#   'Total': '440'},
#  'Psyduck': {'National №': '054',
#   'Type': '\nWater ',
#   'Species': 'Duck Pokémon',
#   'Height': '0.8\xa0m (2′07″)',
#   'Weight': '19.6\xa0kg (43.2\xa0lbs)',
#   'Abilities': '1. Damp2. Cloud NineSwift Swim (hidden ability)',
#   'Local №': "054 (Yellow/Red/Blue)138 (Gold/Silver/Crystal)158 (Ruby/Sapphire/Emerald)054 (FireRed/LeafGreen)043 (Diamond/Pearl)043 (Platinum)140 (HeartGold/SoulSilver)028 (Black 2/White 2)059 (X/Y — Central Kalos)165 (Omega Ruby/Alpha Sapphire)089 (Sun/Moon — Alola dex)107 (U.Sun/U.Moon — Alola dex)054 (Let's Go Pikachu/Let's Go Eevee)146 (The Isle of Armor)",
#   'EV yield': '\n1 Special Attack ',
#   'Catch rate': '\n190 (24.8% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '64',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Field, Water 1',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '50',
#   'Attack': '52',
#   'Defense': '48',
#   'Sp. Atk': '65',
#   'Sp. Def': '50',
#   'Speed': '55',
#   'Total': '320'},
#  'Golduck': {'National №': '055',
#   'Type': '\nWater ',
#   'Species': 'Duck Pokémon',
#   'Height': '1.7\xa0m (5′07″)',
#   'Weight': '76.6\xa0kg (168.9\xa0lbs)',
#   'Abilities': '1. Damp2. Cloud NineSwift Swim (hidden ability)',
#   'Local №': "055 (Yellow/Red/Blue)139 (Gold/Silver/Crystal)159 (Ruby/Sapphire/Emerald)055 (FireRed/LeafGreen)044 (Diamond/Pearl)044 (Platinum)141 (HeartGold/SoulSilver)029 (Black 2/White 2)060 (X/Y — Central Kalos)166 (Omega Ruby/Alpha Sapphire)090 (Sun/Moon — Alola dex)108 (U.Sun/U.Moon — Alola dex)055 (Let's Go Pikachu/Let's Go Eevee)147 (The Isle of Armor)",
#   'EV yield': '\n2 Special Attack ',
#   'Catch rate': '\n75 (9.8% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '175',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Field, Water 1',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '20 (4,884–5,140 steps)\n',
#   'HP': '80',
#   'Attack': '82',
#   'Defense': '78',
#   'Sp. Atk': '95',
#   'Sp. Def': '80',
#   'Speed': '85',
#   'Total': '500'},
#  'Mankey': {'National №': '056',
#   'Type': '\nFighting ',
#   'Species': 'Pig Monkey Pokémon',
#   'Height': '0.5\xa0m (1′08″)',
#   'Weight': '28.0\xa0kg (61.7\xa0lbs)',
# ...
#   'Sp. Def': '20',
#   'Speed': '70',
#   'Total': '470'},
#  'Eiscue': {'National №': '875',
#   'Type': '\nIce ',
#   'Species': 'Penguin Pokémon',
#   'Height': '1.4\xa0m (4′07″)',
#   'Weight': '89.0\xa0kg (196.2\xa0lbs)',
#   'Abilities': '1. Ice Face',
#   'Local №': '370 (Sword/Shield)090 (The Crown Tundra)',
#   'EV yield': '\n2 Defense ',
#   'Catch rate': '\n60 (7.8% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '165',
#   'Growth Rate': 'Slow',
#   'Egg Groups': 'Field, Water 1',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '25 (6,169–6,425 steps)\n',
#   'HP': '75',
#   'Attack': '80',
#   'Defense': '110',
#   'Sp. Atk': '65',
#   'Sp. Def': '90',
#   'Speed': '50',
#   'Total': '470'},
#  'Indeedee': {'National №': '876',
#   'Type': '\nPsychic Normal ',
#   'Species': 'Emotion Pokémon',
#   'Height': '0.9\xa0m (2′11″)',
#   'Weight': '28.0\xa0kg (61.7\xa0lbs)',
#   'Abilities': '1. Inner Focus2. SynchronizePsychic Surge (hidden ability)',
#   'Local №': '337 (Sword/Shield)171 (The Crown Tundra)',
#   'EV yield': '\n2 Special Attack ',
#   'Catch rate': '\n30 (3.9% with PokéBall, full HP)\n',
#   None: '\n140 (higher than normal)\n',
#   'Base Exp.': '166',
#   'Growth Rate': 'Fast',
#   'Egg Groups': 'Fairy',
#   'Gender': '100% male, 0% female',
#   'Egg cycles': '40 (10,024–10,280 steps)\n',
#   'HP': '60',
#   'Attack': '65',
#   'Defense': '55',
#   'Sp. Atk': '105',
#   'Sp. Def': '95',
#   'Speed': '95',
#   'Total': '475'},
#  'Morpeko': {'National №': '877',
#   'Type': '\nElectric Dark ',
#   'Species': 'Two-Sided Pokémon',
#   'Height': '0.3\xa0m (1′00″)',
#   'Weight': '3.0\xa0kg (6.6\xa0lbs)',
#   'Abilities': '1. Hunger Switch',
#   'Local №': '344 (Sword/Shield)104 (The Isle of Armor)157 (The Crown Tundra)',
#   'EV yield': '\n2 Speed ',
#   'Catch rate': '\n180 (23.5% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '153',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Fairy, Field',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '10 (2,314–2,570 steps)\n',
#   'HP': '58',
#   'Attack': '95',
#   'Defense': '58',
#   'Sp. Atk': '70',
#   'Sp. Def': '58',
#   'Speed': '97',
#   'Total': '436'},
#  'Cufant': {'National №': '878',
#   'Type': '\nSteel ',
#   'Species': 'Copperderm Pokémon',
#   'Height': '1.2\xa0m (3′11″)',
#   'Weight': '100.0\xa0kg (220.5\xa0lbs)',
#   'Abilities': '1. Sheer ForceHeavy Metal (hidden ability)',
#   'Local №': '302 (Sword/Shield)108 (The Crown Tundra)',
#   'EV yield': '\n1 Attack ',
#   'Catch rate': '\n190 (24.8% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '66',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Field, Mineral',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '25 (6,169–6,425 steps)\n',
#   'HP': '72',
#   'Attack': '80',
#   'Defense': '49',
#   'Sp. Atk': '40',
#   'Sp. Def': '49',
#   'Speed': '40',
#   'Total': '330'},
#  'Copperajah': {'National №': '879',
#   'Type': '\nSteel ',
#   'Species': 'Copperderm Pokémon',
#   'Height': '3.0\xa0m (9′10″)',
#   'Weight': '650.0\xa0kg (1433.0\xa0lbs)',
#   'Abilities': '1. Sheer ForceHeavy Metal (hidden ability)',
#   'Local №': '303 (Sword/Shield)109 (The Crown Tundra)',
#   'EV yield': '\n2 Attack ',
#   'Catch rate': '\n90 (11.8% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '175',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Field, Mineral',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '25 (6,169–6,425 steps)\n',
#   'HP': '122',
#   'Attack': '130',
#   'Defense': '69',
#   'Sp. Atk': '80',
#   'Sp. Def': '69',
#   'Speed': '30',
#   'Total': '500'},
#  'Dracozolt': {'National №': '880',
#   'Type': '\nElectric Dragon ',
#   'Species': 'Fossil Pokémon',
#   'Height': '1.8\xa0m (5′11″)',
#   'Weight': '190.0\xa0kg (418.9\xa0lbs)',
#   'Abilities': '1. Volt Absorb2. HustleSand Rush (hidden ability)',
#   'Local №': '374 (Sword/Shield)',
#   'EV yield': '\n2 Attack ',
#   'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '177',
#   'Growth Rate': 'Slow',
#   'Egg Groups': 'Undiscovered',
#   'Gender': 'Genderless',
#   'Egg cycles': '35 (8,739–8,995 steps)\n',
#   'HP': '90',
#   'Attack': '100',
#   'Defense': '90',
#   'Sp. Atk': '80',
#   'Sp. Def': '70',
#   'Speed': '75',
#   'Total': '505'},
#  'Arctozolt': {'National №': '881',
#   'Type': '\nElectric Ice ',
#   'Species': 'Fossil Pokémon',
#   'Height': '2.3\xa0m (7′07″)',
#   'Weight': '150.0\xa0kg (330.7\xa0lbs)',
#   'Abilities': '1. Volt Absorb2. StaticSlush Rush (hidden ability)',
#   'Local №': '375 (Sword/Shield)',
#   'EV yield': '\n2 Attack ',
#   'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '177',
#   'Growth Rate': 'Slow',
#   'Egg Groups': 'Undiscovered',
#   'Gender': 'Genderless',
#   'Egg cycles': '35 (8,739–8,995 steps)\n',
#   'HP': '90',
#   'Attack': '100',
#   'Defense': '90',
#   'Sp. Atk': '90',
#   'Sp. Def': '80',
#   'Speed': '55',
#   'Total': '505'},
#  'Dracovish': {'National №': '882',
#   'Type': '\nWater Dragon ',
#   'Species': 'Fossil Pokémon',
#   'Height': '2.3\xa0m (7′07″)',
#   'Weight': '215.0\xa0kg (474.0\xa0lbs)',
#   'Abilities': '1. Water Absorb2. Strong JawSand Rush (hidden ability)',
#   'Local №': '376 (Sword/Shield)',
#   'EV yield': '\n2 Defense ',
#   'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '177',
#   'Growth Rate': 'Slow',
#   'Egg Groups': 'Undiscovered',
#   'Gender': 'Genderless',
#   'Egg cycles': '35 (8,739–8,995 steps)\n',
#   'HP': '90',
#   'Attack': '90',
#   'Defense': '100',
#   'Sp. Atk': '70',
#   'Sp. Def': '80',
#   'Speed': '75',
#   'Total': '505'},
#  'Arctovish': {'National №': '883',
#   'Type': '\nWater Ice ',
#   'Species': 'Fossil Pokémon',
#   'Height': '2.0\xa0m (6′07″)',
#   'Weight': '175.0\xa0kg (385.8\xa0lbs)',
#   'Abilities': '1. Water Absorb2. Ice BodySlush Rush (hidden ability)',
#   'Local №': '377 (Sword/Shield)',
#   'EV yield': '\n2 Defense ',
#   'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '177',
#   'Growth Rate': 'Slow',
#   'Egg Groups': 'Undiscovered',
#   'Gender': 'Genderless',
#   'Egg cycles': '35 (8,739–8,995 steps)\n',
#   'HP': '90',
#   'Attack': '90',
#   'Defense': '100',
#   'Sp. Atk': '80',
#   'Sp. Def': '90',
#   'Speed': '55',
#   'Total': '505'},
#  'Duraludon': {'National №': '884',
#   'Type': '\nSteel Dragon ',
#   'Species': 'Alloy Pokémon',
#   'Height': '1.8\xa0m (5′11″)',
#   'Weight': '40.0\xa0kg (88.2\xa0lbs)',
#   'Abilities': '1. Light Metal2. Heavy MetalStalwart (hidden ability)',
#   'Local №': '371 (Sword/Shield)',
#   'EV yield': '\n2 Special Attack ',
#   'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '187',
#   'Growth Rate': 'Medium Fast',
#   'Egg Groups': 'Dragon, Mineral',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '30 (7,454–7,710 steps)\n',
#   'HP': '70',
#   'Attack': '95',
#   'Defense': '115',
#   'Sp. Atk': '120',
#   'Sp. Def': '50',
#   'Speed': '85',
#   'Total': '535'},
#  'Dreepy': {'National №': '885',
#   'Type': '\nDragon Ghost ',
#   'Species': 'Lingering Pokémon',
#   'Height': '0.5\xa0m (1′08″)',
#   'Weight': '2.0\xa0kg (4.4\xa0lbs)',
#   'Abilities': '1. Clear Body2. InfiltratorCursed Body (hidden ability)',
#   'Local №': '395 (Sword/Shield)110 (The Crown Tundra)',
#   'EV yield': '\n1 Speed ',
#   'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '54',
#   'Growth Rate': 'Slow',
#   'Egg Groups': 'Amorphous, Dragon',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '40 (10,024–10,280 steps)\n',
#   'HP': '28',
#   'Attack': '60',
#   'Defense': '30',
#   'Sp. Atk': '40',
#   'Sp. Def': '30',
#   'Speed': '82',
#   'Total': '270'},
#  'Drakloak': {'National №': '886',
#   'Type': '\nDragon Ghost ',
#   'Species': 'Caretaker Pokémon',
#   'Height': '1.4\xa0m (4′07″)',
#   'Weight': '11.0\xa0kg (24.3\xa0lbs)',
#   'Abilities': '1. Clear Body2. InfiltratorCursed Body (hidden ability)',
#   'Local №': '396 (Sword/Shield)111 (The Crown Tundra)',
#   'EV yield': '\n2 Speed ',
#   'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '144',
#   'Growth Rate': 'Slow',
#   'Egg Groups': 'Amorphous, Dragon',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '40 (10,024–10,280 steps)\n',
#   'HP': '68',
#   'Attack': '80',
#   'Defense': '50',
#   'Sp. Atk': '60',
#   'Sp. Def': '50',
#   'Speed': '102',
#   'Total': '410'},
#  'Dragapult': {'National №': '887',
#   'Type': '\nDragon Ghost ',
#   'Species': 'Stealth Pokémon',
#   'Height': '3.0\xa0m (9′10″)',
#   'Weight': '50.0\xa0kg (110.2\xa0lbs)',
#   'Abilities': '1. Clear Body2. InfiltratorCursed Body (hidden ability)',
#   'Local №': '397 (Sword/Shield)112 (The Crown Tundra)',
#   'EV yield': '\n3 Speed ',
#   'Catch rate': '\n45 (5.9% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '300',
#   'Growth Rate': 'Slow',
#   'Egg Groups': 'Amorphous, Dragon',
#   'Gender': '50% male, 50% female',
#   'Egg cycles': '40 (10,024–10,280 steps)\n',
#   'HP': '88',
#   'Attack': '120',
#   'Defense': '75',
#   'Sp. Atk': '100',
#   'Sp. Def': '75',
#   'Speed': '142',
#   'Total': '600'},
#  'Zacian': {'National №': '888',
#   'Type': '\nFairy Steel ',
#   'Species': 'Warrior Pokémon',
#   'Height': '2.8\xa0m (9′02″)',
#   'Weight': '355.0\xa0kg (782.6\xa0lbs)',
#   'Abilities': '1. Intrepid Sword',
#   'Local №': '398 (Sword/Shield)',
#   'EV yield': '\n3 Speed ',
#   'Catch rate': '\n10 (1.3% with PokéBall, full HP)\n',
#   None: '\n0 (lower than normal)\n',
#   'Base Exp.': '360',
#   'Growth Rate': 'Slow',
#   'Egg Groups': 'Undiscovered',
#   'Gender': 'Genderless',
#   'Egg cycles': '120 (30,584–30,840 steps)\n',
#   'HP': '92',
#   'Attack': '170',
#   'Defense': '115',
#   'Sp. Atk': '80',
#   'Sp. Def': '115',
#   'Speed': '148',
#   'Total': '720'},
#  'Zamazenta': {'National №': '889',
#   'Type': '\nFighting Steel ',
#   'Species': 'Warrior Pokémon',
#   'Height': '2.9\xa0m (9′06″)',
#   'Weight': '785.0\xa0kg (1730.6\xa0lbs)',
#   'Abilities': '1. Dauntless Shield',
#   'Local №': '399 (Sword/Shield)',
#   'EV yield': '\n3 Speed ',
#   'Catch rate': '\n10 (1.3% with PokéBall, full HP)\n',
#   None: '\n0 (lower than normal)\n',
#   'Base Exp.': '360',
#   'Growth Rate': 'Slow',
#   'Egg Groups': 'Undiscovered',
#   'Gender': 'Genderless',
#   'Egg cycles': '120 (30,584–30,840 steps)\n',
#   'HP': '92',
#   'Attack': '130',
#   'Defense': '145',
#   'Sp. Atk': '80',
#   'Sp. Def': '145',
#   'Speed': '128',
#   'Total': '720'},
#  'Eternatus': {'National №': '890',
#   'Type': '\nPoison Dragon ',
#   'Species': 'Gigantic Pokémon',
#   'Height': '20.0\xa0m (65′07″)',
#   'Weight': '950.0\xa0kg (2094.4\xa0lbs)',
#   'Abilities': '1. Pressure',
#   'Local №': '400 (Sword/Shield)',
#   'EV yield': '\n3 HP ',
#   'Catch rate': '\n255 (33.3% with PokéBall, full HP)\n',
#   None: '\n0 (lower than normal)\n',
#   'Base Exp.': '345',
#   'Growth Rate': 'Slow',
#   'Egg Groups': 'Undiscovered',
#   'Gender': 'Genderless',
#   'Egg cycles': '120 (30,584–30,840 steps)\n',
#   'HP': '140',
#   'Attack': '85',
#   'Defense': '95',
#   'Sp. Atk': '145',
#   'Sp. Def': '95',
#   'Speed': '130',
#   'Total': '690'},
#  'Kubfu': {'National №': '891',
#   'Type': '\nFighting ',
#   'Species': 'Wushu Pokémon',
#   'Height': '0.6\xa0m (2′00″)',
#   'Weight': '12.0\xa0kg (26.5\xa0lbs)',
#   'Abilities': '1. Inner Focus',
#   'Local №': '100 (The Isle of Armor)',
#   'EV yield': '\n1 Attack ',
#   'Catch rate': '\n3 (0.4% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '77',
#   'Growth Rate': 'Slow',
#   'Egg Groups': 'Undiscovered',
#   'Gender': '87.5% male, 12.5% female',
#   'Egg cycles': '120 (30,584–30,840 steps)\n',
#   'HP': '60',
#   'Attack': '90',
#   'Defense': '60',
#   'Sp. Atk': '53',
#   'Sp. Def': '50',
#   'Speed': '72',
#   'Total': '385'},
#  'Urshifu': {'National №': '892',
#   'Type': '\nFighting Dark ',
#   'Species': 'Wushu Pokémon',
#   'Height': '1.9\xa0m (6′03″)',
#   'Weight': '105.0\xa0kg (231.5\xa0lbs)',
#   'Abilities': '1. Unseen Fist',
#   'Local №': '101 (The Isle of Armor)',
#   'EV yield': '\n3 Attack ',
#   'Catch rate': '\n3 (0.4% with PokéBall, full HP)\n',
#   None: '\n50 (normal)\n',
#   'Base Exp.': '275',
#   'Growth Rate': 'Slow',
#   'Egg Groups': 'Undiscovered',
#   'Gender': '87.5% male, 12.5% female',
#   'Egg cycles': '120 (30,584–30,840 steps)\n',
#   'HP': '100',
#   'Attack': '130',
#   'Defense': '100',
#   'Sp. Atk': '63',
#   'Sp. Def': '60',
#   'Speed': '97',
#   'Total': '550'},
#  'Zarude': {'National №': '893',
#   'Type': '\nDark Grass ',
#   'Species': 'Rogue Monkey Pokémon',
#   'Height': '1.8\xa0m (5′11″)',
#   'Weight': '70.0\xa0kg (154.3\xa0lbs)',
#   'Abilities': '1. Leaf Guard',
#   'Local №': '211 (The Isle of Armor)',
#   'EV yield': '\n3 Attack ',
#   'Catch rate': '\n3 (0.4% with PokéBall, full HP)\n',
#   None: '\n0 (lower than normal)\n',
#   'Base Exp.': '300',
#   'Growth Rate': 'Slow',
#   'Egg Groups': 'Undiscovered',
#   'Gender': 'Genderless',
#   'Egg cycles': '120 (30,584–30,840 steps)\n',
#   'HP': '105',
#   'Attack': '120',
#   'Defense': '105',
#   'Sp. Atk': '70',
#   'Sp. Def': '95',
#   'Speed': '105',
#   'Total': '600'},
#  'Regieleki': {'National №': '894',
#   'Type': '\nElectric ',
#   'Species': 'Electron Pokémon',
#   'Height': '1.2\xa0m (3′11″)',
#   'Weight': '145.0\xa0kg (319.7\xa0lbs)',
#   'Abilities': '1. Transistor',
#   'Local №': '200 (The Crown Tundra)',
#   'EV yield': '\n3 Speed ',
#   'Catch rate': '\n3 (0.4% with PokéBall, full HP)\n',
#   None: '\n35 (lower than normal)\n',
#   'Base Exp.': '290',
#   'Growth Rate': 'Slow',
#   'Egg Groups': 'Undiscovered',
#   'Gender': 'Genderless',
#   'Egg cycles': '120 (30,584–30,840 steps)\n',
#   'HP': '80',
#   'Attack': '100',
#   'Defense': '50',
#   'Sp. Atk': '100',
#   'Sp. Def': '50',
#   'Speed': '200',
#   'Total': '580'},
#  'Regidrago': {'National №': '895',
#   'Type': '\nDragon ',
#   'Species': 'Dragon Orb Pokémon',
#   'Height': '2.1\xa0m (6′11″)',
#   'Weight': '200.0\xa0kg (440.9\xa0lbs)',
#   'Abilities': "1. Dragon's Maw",
#   'Local №': '201 (The Crown Tundra)',
#   'EV yield': '\n3 HP ',
#   'Catch rate': '\n3 (0.4% with PokéBall, full HP)\n',
#   None: '\n35 (lower than normal)\n',
#   'Base Exp.': '290',
#   'Growth Rate': 'Slow',
#   'Egg Groups': 'Undiscovered',
#   'Gender': 'Genderless',
#   'Egg cycles': '120 (30,584–30,840 steps)\n',
#   'HP': '200',
#   'Attack': '100',
#   'Defense': '50',
#   'Sp. Atk': '100',
#   'Sp. Def': '50',
#   'Speed': '80',
#   'Total': '580'},
#  'Glastrier': {'National №': '896',
#   'Type': '\nIce ',
#   'Species': 'Wild Horse Pokémon',
#   'Height': '2.2\xa0m (7′03″)',
#   'Weight': '800.0\xa0kg (1763.7\xa0lbs)',
#   'Abilities': '1. Chilling Neigh',
#   'Local №': '208 (The Crown Tundra)',
#   'EV yield': '\n3 Attack ',
#   'Catch rate': '\n3 (0.4% with PokéBall, full HP)\n',
#   None: '\n35 (lower than normal)\n',
#   'Base Exp.': '290',
#   'Growth Rate': 'Slow',
#   'Egg Groups': 'Undiscovered',
#   'Gender': 'Genderless',
#   'Egg cycles': '120 (30,584–30,840 steps)\n',
#   'HP': '100',
#   'Attack': '145',
#   'Defense': '130',
#   'Sp. Atk': '65',
#   'Sp. Def': '110',
#   'Speed': '30',
#   'Total': '580'},
#  'Spectrier': {'National №': '897',
#   'Type': '\nGhost ',
#   'Species': 'Swift Horse Pokémon',
#   'Height': '2.0\xa0m (6′07″)',
#   'Weight': '44.5\xa0kg (98.1\xa0lbs)',
#   'Abilities': '1. Grim Neigh',
#   'Local №': '209 (The Crown Tundra)',
#   'EV yield': '\n3 Special Attack ',
#   'Catch rate': '\n3 (0.4% with PokéBall, full HP)\n',
#   None: '\n35 (lower than normal)\n',
#   'Base Exp.': '290',
#   'Growth Rate': 'Slow',
#   'Egg Groups': 'Undiscovered',
#   'Gender': 'Genderless',
#   'Egg cycles': '120 (30,584–30,840 steps)\n',
#   'HP': '100',
#   'Attack': '65',
#   'Defense': '60',
#   'Sp. Atk': '145',
#   'Sp. Def': '80',
#   'Speed': '130',
#   'Total': '580'},
#  'Calyrex': {'National №': '898',
#   'Type': '\nPsychic Grass ',
#   'Species': 'King Pokémon',
#   'Height': '1.1\xa0m (3′07″)',
#   'Weight': '7.7\xa0kg (17.0\xa0lbs)',
#   'Abilities': '1. Unnerve',
#   'Local №': '210 (The Crown Tundra)',
#   'EV yield': '\n3 HP ',
#   'Catch rate': '\n3 (0.4% with PokéBall, full HP)\n',
#   None: '\n100 (higher than normal)\n',
#   'Base Exp.': '250',
#   'Growth Rate': 'Slow',
#   'Egg Groups': 'Undiscovered',
#   'Gender': 'Genderless',
#   'Egg cycles': '120 (30,584–30,840 steps)\n',
#   'HP': '100',
#   'Attack': '80',
#   'Defense': '80',
#   'Sp. Atk': '80',
#   'Sp. Def': '80',
#   'Speed': '80',
#   'Total': '500'}}

# %% [markdown]
# #### Récupération des images de chacun des pokémons et enregistrement dans un dossier

# %%
url_pokemons_list = "https://pokemondb.net/pokedex/all"
icon_url_list = []  # Liste des url des images de pokemons (sous forme d'icônes)

req = Request(url_pokemons_list, headers={'User-Agent': 'Mozilla/5.0'})
html = urlopen(req).read().decode('utf-8')
page = bs4.BeautifulSoup(html, 'html.parser')

table = page.find('table', id = 'pokedex')
for item in table.findAll('span', {'class':'img-fixed icon-pkmn'}):
    icon_url_list.append(item.get("data-src"))
icon_url_list[:10]
# Out:
# ['https://img.pokemondb.net/sprites/sword-shield/icon/bulbasaur.png',
#  'https://img.pokemondb.net/sprites/sword-shield/icon/ivysaur.png',
#  'https://img.pokemondb.net/sprites/sword-shield/icon/venusaur.png',
#  'https://img.pokemondb.net/sprites/sword-shield/icon/venusaur-mega.png',
#  'https://img.pokemondb.net/sprites/sword-shield/icon/charmander.png',
#  'https://img.pokemondb.net/sprites/sword-shield/icon/charmeleon.png',
#  'https://img.pokemondb.net/sprites/sword-shield/icon/charizard.png',
#  'https://img.pokemondb.net/sprites/sword-shield/icon/charizard-mega-x.png',
#  'https://img.pokemondb.net/sprites/sword-shield/icon/charizard-mega-y.png',
#  'https://img.pokemondb.net/sprites/sword-shield/icon/squirtle.png']

# %% [markdown]
# How to Download an Image Using Python : https://towardsdatascience.com/how-to-download-an-image-using-python-38a75cfa21c

# %%
## Importing Necessary Modules
import requests # to get image from the web
import shutil # to save it locally

## Set up the image URL and filename
image_url = "https://img.pokemondb.net/sprites/sword-shield/icon/bulbasaur.png"
filename = image_url.split("/")[-1]

# Open the url image, set stream to True, this will return the stream content.
r = requests.get(image_url, stream = True)

# Check if the image was retrieved successfully
if r.status_code == 200:
    # Set decode_content value to True, otherwise the downloaded image file's size will be zero.
    r.raw.decode_content = True
    
    # Open a local file with wb ( write binary ) permission.
    with open(filename,'wb') as f:
        shutil.copyfileobj(r.raw, f)
        
    print('Image sucessfully Downloaded: ',filename)
else:
    print('Image Couldn\'t be retreived')
# Out:
# Image sucessfully Downloaded:  bulbasaur.png

# %% [markdown]
# Enregistrement de toutes les images dans un dossier `icon` dans le répertoire courant

# %%
# Création du dossier `icon`
import os
if not os.path.exists('icon'):
    os.makedirs('icon')

# Récupération des images
for icon_url in icon_url_list:
    filename = icon_url.split("/")[-1]

    # Open the url image, set stream to True, this will return the stream content.
    r = requests.get(icon_url, stream = True)

    # Check if the image was retrieved successfully
    if r.status_code == 200:
        # Set decode_content value to True, otherwise the downloaded image file's size will be zero.
        r.raw.decode_content = True
    
        # Open a local file with wb ( write binary ) permission.
        with open(os.path.join('icon',filename) ,'wb') as f:
            shutil.copyfileobj(r.raw, f)
